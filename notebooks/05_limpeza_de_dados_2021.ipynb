# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys

#import sys
sys.path.append('../src')
import data_cleaner as dc

# %%
RAW_DATA_DIR, PROCESSED_DATA_DIR = dc.caminho_para_dataset()

# %%
try:
  df_2021 = pd.read_csv(RAW_DATA_DIR/'State_of_data_2021.csv')
  print("arquivo encontrado")
except FileNotFoundError as e:
  print('Houve um erro, nao encontramos o arquivo' + e)
# Out:
# arquivo encontrado
# /tmp/ipykernel_14506/2075670874.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.read_csv(RAW_DATA_DIR/'State_of_data_2021.csv')

# %%
df_2021
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
# 1     zdl2n19yhgpnoaco6kkczdl2nwv9zwrt                39.0
# 2     vsamqp2un3q7us84mgvsams5fulsmcoh                30.0
# 3     v31ab41botodnsv31zgg4k34zzojy81l                38.0
# 4     ubhu8ntvm4xc0sfkdubhu80e973eek0k                36.0
# ...                                ...                 ...
# 2640  07nvo8cdy377a46gon207nvjebwe65zg                40.0
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg                27.0
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18                24.0
# 2643  075h3v2z19if04yn7o075h3vhifl38rw                38.0
# 2644  037usz1h2yip96dgil4mhj037uszw1gk                27.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         35-39           Masculino
# 1                         35-39           Masculino
# 2                         30-34           Masculino
# ...

# %%
print(df_2021.columns.tolist())
# Out:
# ["('P0', 'id')", "('P1_a ', 'Idade')", "('P1_a_a ', 'Faixa idade')", "('P1_b ', 'Genero')", "('P1_e ', 'Estado onde mora')", "('P1_e_a ', 'uf onde mora')", "('P1_e_b ', 'Regiao onde mora')", "('P1_g_b ', 'Regiao de origem')", "('P1_g_c ', 'Mudou de Estado?')", "('P1_h ', 'Nivel de Ensino')", "('P1_i ', 'Área de Formação')", "('P2_a ', 'Qual sua situação atual de trabalho?')", "('P2_b ', 'Setor')", "('P2_c ', 'Numero de Funcionarios')", "('P2_d ', 'Gestor?')", "('P2_e ', 'Cargo como Gestor')", "('P2_f ', 'Cargo Atual')", "('P2_g ', 'Nivel')", "('P2_h ', 'Faixa salarial')", "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')", "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')", "('P2_k ', 'Você está satisfeito na sua empresa atual?')", "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')", "('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')"
# ...

# %%
mapa_renomeacao_2021 = {
    # === DEMOGRAFIA E EXPERIÊNCIA ===
    "('P0', 'id')": 'id_participante',
    "('P1_a ', 'Idade')": 'idade',
    "('P1_a_a ', 'Faixa idade')": 'faixa_idade',
    "('P1_b ', 'Genero')": 'genero',
    "('P1_e_a ', 'uf onde mora')": 'uf_residencia',
    "('P1_e_b ', 'Regiao onde mora')": 'regiao_residencia',
    "('P1_g_b ', 'Regiao de origem')": 'regiao_origem',
    "('P1_h ', 'Nivel de Ensino')": 'nivel_ensino',
    "('P1_i ', 'Área de Formação')": 'area_formacao',

    # === REMUNERAÇÃO E CARREIRA ===
    "('P2_h ', 'Faixa salarial')": 'faixa_salarial',
    "('P2_g ', 'Nivel')": 'nivel_hierarquico',
    "('P2_f ', 'Cargo Atual')": 'cargo_atual',
    "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')": 'experiencia_dados_anos',
    "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')": 'experiencia_ti_anos',
    "('P2_a ', 'Qual sua situação atual de trabalho?')": 'situacao_trabalho',
    "('P2_b ', 'Setor')": 'setor_atuacao',
    "('P2_c ', 'Numero de Funcionarios')": 'tamanho_empresa',
    "('P2_d ', 'Gestor?')": 'atua_como_gestor',

    # === FERRAMENTAS E TECNOLOGIAS (MULTISELEÇÃO E PRINCIPAIS) ===
    "('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')": 'linguagens_usadas_dia_a_dia',
    "('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')": 'linguagem_principal',
    # "('P4_f ', ...): A linguagem PREFERIDA não foi perguntada em 2021
    "('P4_f ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')": 'bancos_dados_usados_dia_a_dia',
    "('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')": 'clouds_utilizadas',
    "('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')": 'ferramentas_bi_usadas_dia_a_dia',

    # === MODELO DE TRABALHO E SATISFAÇÃO ===
    "('P2_q ', 'Atualmente qual a sua forma de trabalho?')": 'modelo_trabalho_atual',
    "('P2_r ', 'Qual a forma de trabalho ideal para você?')": 'modelo_trabalho_ideal',
    "('P2_k ', 'Você está satisfeito na sua empresa atual?')": 'satisfacao_trabalho',
    "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')": 'motivos_insatisfacao',
    "('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')": 'planos_mudar_emprego',
    "('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')": 'entrevistas_ultimos_6m',
    "('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')": 'criterios_escolha_emprego',

    # === CONTEXTO DA EMPRESA E GESTÃO ===
    "('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')": 'tamanho_equipe_dados',
    "('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')": 'desafios_gestor',

    # === BUSCA POR EMPREGO ===
    "('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')": 'tempo_busca_emprego_meses',
    "('P5_b ', 'Qual oportunidade você está buscando?')": 'tipo_oportunidade_buscada'
}

# %%
len(mapa_renomeacao_2021)
# Out:
# 34

# %%
df_2021_renomeado = df_2021.rename(columns=mapa_renomeacao_2021)

# %%
df_2021_renomeado
# Out:
#                        id_participante  idade faixa_idade     genero  \
# 0     qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s   38.0       35-39  Masculino
# 1     zdl2n19yhgpnoaco6kkczdl2nwv9zwrt   39.0       35-39  Masculino
# 2     vsamqp2un3q7us84mgvsams5fulsmcoh   30.0       30-34  Masculino
# 3     v31ab41botodnsv31zgg4k34zzojy81l   38.0       35-39   Feminino
# 4     ubhu8ntvm4xc0sfkdubhu80e973eek0k   36.0       35-39  Masculino
# ...                                ...    ...         ...        ...
# 2640  07nvo8cdy377a46gon207nvjebwe65zg   40.0       40-44  Masculino
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg   27.0       25-29  Masculino
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18   24.0       22-24  Masculino
# 2643  075h3v2z19if04yn7o075h3vhifl38rw   38.0       35-39  Masculino
# 2644  037usz1h2yip96dgil4mhj037uszw1gk   27.0       25-29   Feminino
#
#      ('P1_e ', 'Estado onde mora') uf_residencia regiao_residencia  \
# 0                       Ceará (CE)            CE          Nordeste
# ...

# %% [markdown]
# ## 3 - tratando coluna salário

# %%
df_2021_renomeado['faixa_salarial'].value_counts()
# Out:
# faixa_salarial
# de R$ 8.001/mês a R$ 12.000/mês     479
# de R$ 4.001/mês a R$ 6.000/mês      403
# de R$ 6.001/mês a R$ 8.000/mês      393
# de R$ 12.001/mês a R$ 16.000/mês    263
# de R$ 3.001/mês a R$ 4.000/mês      183
# de R$ 2.001/mês a R$ 3000/mês       180
# de R$ 16.001/mês a R$ 20.000/mês    129
# de R$ 1.001/mês a R$ 2.000/mês      126
# de R$ 20.001/mês a R$ 25.000/mês     62
# de R$ 25.001/mês a R$ 30.000/mês     43
# de R$ 30.001/mês a R$ 40.000/mês     38
# Acima de R$ 40.001/mês               34
# Menos de R$ 1.000/mês                32
# Name: count, dtype: int64

# %%
len(df_2021_renomeado['faixa_salarial'].value_counts())
# Out:
# 13

# %%
df_2021_renomeado['faixa_salarial'].isnull().sum()
# Out:
# np.int64(280)

# %%
df_2021_renomeado['faixa_salarial'].apply(dc.converter_faixa_salarial).head(20)
# Out:
# 0      5000.5
# 1      7000.5
# 2     10000.5
# 3     14000.5
# 4     10000.5
# 5     10000.5
# 6      3500.5
# 7     14000.5
# 8      5000.5
# 9      5000.5
# 10    35000.5
# 11     7000.5
# 12    22500.5
# 13     5000.5
# 14     3500.5
# 15    10000.5
# 16    10000.5
# 17     5000.5
# 18     7000.5
# 19     7000.5
# Name: faixa_salarial, dtype: float64

# %%
try:
  print('criando coluna salario_medio_mensal')
  df_2021_renomeado['salario_medio_mensal'] = df_2021_renomeado['faixa_salarial'].apply(dc.converter_faixa_salarial)
  print(df_2021_renomeado['salario_medio_mensal'].head(10))
except Exception as e:
  print("Ocorreu um erro " + e)
# Out:
# criando coluna salario_medio_mensal
# 0     5000.5
# 1     7000.5
# 2    10000.5
# 3    14000.5
# 4    10000.5
# 5    10000.5
# 6     3500.5
# 7    14000.5
# 8     5000.5
# 9     5000.5
# Name: salario_medio_mensal, dtype: float64

# %%
df_2021_renomeado[['salario_medio_mensal', 'faixa_salarial']].head(5)
# Out:
#    salario_medio_mensal                    faixa_salarial
# 0                5000.5    de R$ 4.001/mês a R$ 6.000/mês
# 1                7000.5    de R$ 6.001/mês a R$ 8.000/mês
# 2               10000.5   de R$ 8.001/mês a R$ 12.000/mês
# 3               14000.5  de R$ 12.001/mês a R$ 16.000/mês
# 4               10000.5   de R$ 8.001/mês a R$ 12.000/mês

# %% [markdown]
# ## 4- Limpando coluna cargo

# %%
df_2021_renomeado['nivel_hierarquico'].value_counts()
# Out:
# nivel_hierarquico
# Pleno     658
# Júnior    621
# Sênior    578
# Name: count, dtype: int64

# %%
print(df_2021_renomeado['nivel_hierarquico'].isnull().sum())
print(df_2021_renomeado['cargo_atual'].isnull().sum())
# Out:
# 788
# 788

# %%
df_2021_renomeado['cargo_atual'].value_counts()
# Out:
# cargo_atual
# Cientista de Dados/Data Scientist                          357
# Analista de BI/BI Analyst/Analytics Engineer               338
# Analista de Dados/Data Analyst                             324
# Engenheiro de Dados/Data Engineer                          300
# Outro                                                      113
# Analista de Negócios/Business Analyst                       96
# Desenvolvedor ou Engenheiro de Software                     92
# Engenheiro de Machine Learning/ML Engineer                  48
# Outras Engenharias (não inclui dev)                         33
# Estatístico                                                 25
# Analista de Inteligência de Mercado/Market Intelligence     18
# Analista Administrativo                                     18
# DBA/Administrador de Banco de Dados                         14
# Analista de Sistemas/Analista de TI                         14
# Analista de Marketing                                       14
# ...

# %%
df_2021_renomeado['grupo_cargo'] = df_2021_renomeado['cargo_atual'].apply(dc.agrupar_cargo)

# %%
df_2021_renomeado['grupo_cargo'].value_counts()
# Out:
# grupo_cargo
# Não se aplica/Outra área      788
# Outros                        365
# Cientista de Dados            357
# Analista de BI                338
# Analista de Dados             324
# Engenheiro de Dados           323
# Analista de Negócios           96
# Engenheiro de ML               48
# Gestão de Produto de Dados      6
# Name: count, dtype: int64

# %% [markdown]
# ## 5 - Tratando coluna 'experiencia_dados_anos'

# %%
df_2021_renomeado['experiencia_dados_anos'].value_counts()
# Out:
# experiencia_dados_anos
# de 2 a 3 anos                             487
# de 1 a 2 anos                             446
# de 4 a 5 anos                             389
# Menos de 1 ano                            384
# de 6 a 10 anos                            276
# Mais de 10 anos                           261
# Não tenho experiência na área de dados    122
# Name: count, dtype: int64

# %%
df_2021_renomeado['experiencia_dados_anos'].isnull().sum()
# Out:
# np.int64(280)

# %%
len(df_2021_renomeado['experiencia_dados_anos'].value_counts())
# Out:
# 7

# %%
df_2021_renomeado['experiencia_anos_num'] = df_2021_renomeado['experiencia_dados_anos'].apply(dc.converter_experiencia)

# %%
df_2021_renomeado[['experiencia_anos_num', 'experiencia_dados_anos']]
# Out:
#       experiencia_anos_num experiencia_dados_anos
# 0                     12.0        Mais de 10 anos
# 1                      2.5          de 2 a 3 anos
# 2                      1.5          de 1 a 2 anos
# 3                     12.0        Mais de 10 anos
# 4                      1.5          de 1 a 2 anos
# ...                    ...                    ...
# 2640                   NaN                    NaN
# 2641                   4.5          de 4 a 5 anos
# 2642                   2.5          de 2 a 3 anos
# 2643                   NaN                    NaN
# 2644                   NaN                    NaN
#
# [2645 rows x 2 columns]

# %%
df_2021_renomeado['experiencia_anos_num'].isnull().sum()
# Out:
# np.int64(280)

# %% [markdown]
# ## 6 - Criando coluna ano

# %%
df_2021_renomeado['ano'] = 2021

# %%
df_2021_renomeado['ano']
# Out:
# 0       2021
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 2640    2021
# 2641    2021
# 2642    2021
# 2643    2021
# 2644    2021
# Name: ano, Length: 2645, dtype: int64

# %% [markdown]
# ## 7 - Salvando o arquivo limpo

# %%
output_path = PROCESSED_DATA_DIR / 'state_of_data_2021_limpo.csv'
df_2021_renomeado.to_csv(output_path, index=False)
