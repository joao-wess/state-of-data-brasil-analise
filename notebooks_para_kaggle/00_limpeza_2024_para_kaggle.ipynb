# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys

sys.path.append('../src')
import data_cleaner as dc

# %%
RAW_DATA_DIR, PROCESSED_DATA_DIR = dc.caminho_para_dataset()

# %%
try:
  df_2024_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2024_limpo.csv')
  print('arquivo encontrado')
except FileNotFoundError as e: 
  print("Arquivo nao encontrado " + e)
# Out:
# arquivo encontrado

# %%
print(df_2024_kaggle.columns.tolist())
# Out:
# ['id_participante', 'data_envio', 'idade', 'faixa_idade', 'genero', 'etnia', 'pcd', 'experiencia_prejudicada', '1.e.1_Não acredito que minha experiência profissional seja afetada', 'prejudicado_raca_etnia', 'prejudicado_genero', 'prejudicado_pcd', 'uf_residencia', '1.f.1_Quantidade de oportunidades de emprego/vagas recebidas', '1.f.2_Senioridade das vagas recebidas em relação à sua experiência', '1.f.3_Aprovação em processos seletivos/entrevistas', '1.f.4_Oportunidades de progressão de carreira', '1.f.5_Velocidade de progressão de carreira', '1.f.6_Nível de cobrança no trabalho/Stress no trabalho', '1.f.7_Atenção dada pelas pessoas diante das minhas opiniões e ideias', '1.f.8_Relação com outras pessoas da empresa, em momentos de trabalho', '1.f.9_Relação com outras pessoas da empresa, em momentos de integração e outros momentos fora do trabalho', 'regiao_residencia', '1.f_aspectos_prejudicados', 'uf_origem', 'regiao_origem', '1.g_vive_no_brasil', '1.h_pais_onde_mora', '1.i_estado_ond
# ...

# %%
len(df_2024_kaggle.columns.tolist())
# Out:
# 423

# %%
mapa_renomeacao_2024 = {
    # === NOVAS COLUNAS MAPEADAS ===
    "id_participante": "id_participante",
    "data_envio": "data_envio",
    "idade": "idade",
    "faixa_idade": "faixa_idade",
    "genero": "genero",
    "etnia": "etnia",
    "pcd": "pcd",
    "experiencia_prejudicada": "experiencia_prejudicada",
    "uf_residencia": "uf_residencia",
    "regiao_residencia": "regiao_residencia",
    "uf_origem": "uf_origem",
    "regiao_origem": "regiao_origem",
    "nivel_ensino": "nivel_ensino",
    "area_formacao": "area_formacao",
    "situacao_trabalho": "situacao_trabalho",
    "setor_atuacao": "setor_atuacao",
    "tamanho_empresa": "tamanho_empresa",
    "atua_como_gestor": "atua_como_gestor",
    "cargo_atual": "cargo_atual",
    "nivel_hierarquico": "nivel_hierarquico",
    "faixa_salarial": "faixa_salarial",
    "experiencia_dados_anos": "experiencia_dados_anos",
    "experiencia_ti_anos": "experiencia_ti_anos",
    "satisfacao_trabalho": "satisfacao_trabalho",
    "motivos_insatisfacao": "motivos_insatisfacao",
    "entrevistas_ultimos_6m": "entrevistas_ultimos_6m",
    "planos_mudar_emprego": "planos_mudar_emprego",
    "criterios_escolha_emprego": "criterios_escolha_emprego",
    "empresa_teve_layoff_2024": "empresa_teve_layoff",
    "modelo_trabalho_atual": "modelo_trabalho_atual",
    "modelo_trabalho_ideal": "modelo_trabalho_ideal",
    "tamanho_equipe_dados": "tamanho_equipe_dados",
    "ano": "ano",
    "linguagens_usadas_dia_a_dia": "linguagens_usadas_dia_a_dia",
    "linguagem_principal": "linguagem_principal",
    "linguagem_preferida": "linguagem_preferida",
    "bancos_dados_usados_dia_a_dia": "bancos_dados_usados_dia_a_dia",
    "clouds_utilizadas": "clouds_utilizadas",
    "cloud_preferida": "cloud_preferida",
    "ferramentas_bi_usadas_dia_a_dia": "ferramentas_bi_usadas_dia_a_dia",
    "bi_preferida": "bi_preferida",
    "objetivo_profissional": "objetivo_profissional",
    "tipo_oportunidade_buscada": "tipo_oportunidade_buscada",
    "tempo_busca_emprego_meses": "tempo_busca_emprego_meses",
    "uso_ia_generativa_trabalho": "uso_ia_generativa_trabalho",
    "ia_generativa_prioridade": "ia_generativa_prioridade",
    "experiencia_prejudicada_raca_etnia": "experiencia_prejudicada_raca_etnia",
    "experiencia_prejudicada_genero": "experiencia_prejudicada_genero",
    "experiencia_prejudicada_pcd": "experiencia_prejudicada_pcd",
    "desafios_gestor": "desafios_gestor",
    "rotina_engenheiro_dados": "rotina_engenheiro_dados",
    "ferramentas_etl_engineer": "ferramentas_etl_engineer",
    "rotina_analista_dados": "rotina_analista_dados",
    "ferramentas_etl_analyst": "ferramentas_etl_analyst",
    "rotina_cientista_dados": "rotina_cientista_dados",
    "tecnicas_ml_cientista": "tecnicas_ml_cientista",
    "tecnologias_cientista": "tecnologias_cientista",
    # --- Tema: Experiência Profissional Prejudicada ---
    '1.e.1_Não acredito que minha experiência profissional seja afetada': 'prejudicado_acredita_nao_ser_afetado',
    '1.e.2_Sim, devido a minha Cor/Raça/Etnia': 'prejudicado_motivo_raca_etnia',
    '1.e.3_Sim, devido a minha identidade de gênero': 'prejudicado_motivo_genero',
    '1.e.4_Sim, devido ao fato de ser PCD': 'prejudicado_motivo_pcd',
    '1.f_aspectos_prejudicados': 'prejudicado_aspectos_lista',
    '1.f.1_Quantidade de oportunidades de emprego/vagas recebidas': 'prejudicado_aspecto_qtd_oportunidades',
    '1.f.2_Senioridade das vagas recebidas em relação à sua experiência': 'prejudicado_aspecto_senioridade_vagas',
    '1.f.3_Aprovação em processos seletivos/entrevistas': 'prejudicado_aspecto_aprovacao_processos',
    '1.f.4_Oportunidades de progressão de carreira': 'prejudicado_aspecto_oportunidade_progressao',
    '1.f.5_Velocidade de progressão de carreira': 'prejudicado_aspecto_velocidade_progressao',
    '1.f.6_Nível de cobrança no trabalho/Stress no trabalho': 'prejudicado_aspecto_cobranca_stress',
    '1.f.7_Atenção dada pelas pessoas diante das minhas opiniões e ideias': 'prejudicado_aspecto_atencao_ideias',
    '1.f.8_Relação com outras pessoas da empresa, em momentos de trabalho': 'prejudicado_aspecto_relacao_trabalho',
    '1.f.9_Relação com outras pessoas da empresa, em momentos de integração e outros momentos fora do trabalho': 'prejudicado_aspecto_relacao_integracao',

    # --- Tema: Demografia Adicional ---
    '1.g_vive_no_brasil': 'vive_no_brasil',
    '1.h_pais_onde_mora': 'pais_residencia',
    '1.i_estado_onde_mora': 'estado_residencia',
    '1.j_vive_no_estado_de_formacao': 'vive_no_estado_formacao',
    '1.k_estado_de_origem': 'estado_origem',

    # --- Tema: Detalhes do Trabalho ---
    '2.e_cargo_como_gestor': 'cargo_gestor',
    '2.t_atitude_em_caso_de_retorno_presencial': 'atitude_retorno_presencial',

    # --- Tema: Motivos de Satisfação/Insatisfação e Critérios (Múltipla Escolha) ---
    '2.l.1_Remuneração/Salário': 'satisfacao_fator_remuneracao',
    '2.l.2_Benefícios': 'satisfacao_fator_beneficios',
    '2.l.3_Propósito do trabalho e da empresa': 'satisfacao_fator_proposito',
    '2.l.4_Flexibilidade de trabalho remoto': 'satisfacao_fator_flexibilidade',
    '2.l.5_Ambiente e clima de trabalho': 'satisfacao_fator_ambiente',
    '2.l.6_Oportunidade de aprendizado e trabalhar com referências': 'satisfacao_fator_aprendizado',
    '2.l.7_Oportunidades de crescimento': 'satisfacao_fator_crescimento',
    '2.l.8_Maturidade da empresa em termos de tecnologia e dados': 'satisfacao_fator_maturidade_empresa',
    '2.l.9_Relação com os gestores e líderes': 'satisfacao_fator_relacao_gestores',
    '2.l.10_Reputação que a empresa tem no mercado': 'satisfacao_fator_reputacao_empresa',
    '2.l.11_Gostaria de trabalhar em outra área': 'satisfacao_fator_desejo_mudar_area',
    '2.o.1_Remuneração/Salário': 'criterio_escolha_remuneracao',
    '2.o.2_Benefícios': 'criterio_escolha_beneficios',
    '2.o.3_Propósito do trabalho e da empresa': 'criterio_escolha_proposito',
    '2.o.4_Flexibilidade de trabalho remoto': 'criterio_escolha_flexibilidade',
    '2.o.5_Ambiente e clima de trabalho': 'criterio_escolha_ambiente',
    '2.o.6_Oportunidade de aprendizado e trabalhar com referências': 'criterio_escolha_aprendizado',
    '2.o.7_Plano de carreira e oportunidades de crescimento': 'criterio_escolha_plano_carreira',
    '2.o.8_Maturidade da empresa em termos de tecnologia e dados': 'criterio_escolha_maturidade_empresa',
    '2.o.9_Qualidade dos gestores e líderes': 'criterio_escolha_qualidade_gestores',
    '2.o.10_Reputação que a empresa tem no mercado': 'criterio_escolha_reputacao_empresa',

    # --- Tema: Detalhes da Equipe de Dados e Gestão ---
    '3.b_cargos_no_time_de_dados_da_empresa': 'empresa_cargos_dados_lista',
    '3.b.1_Analytics Engineer': 'empresa_tem_analytics_engineer',
    '3.b.2_Engenharia de Dados/Data Engineer': 'empresa_tem_engenheiro_dados',
    '3.b.3_Analista de Dados/Data Analyst': 'empresa_tem_analista_dados',
    '3.b.4_Cientista de Dados/Data Scientist': 'empresa_tem_cientista_dados',
    '3.b.5_Database Administrator/DBA': 'empresa_tem_dba',
    '3.b.6_Analista de Business Intelligence/BI': 'empresa_tem_analista_bi',
    '3.b.7_Arquiteto de Dados/Data Architect': 'empresa_tem_arquiteto_dados',
    '3.b.8_Data Product Manager/DPM': 'empresa_tem_dpm',
    '3.b.9_Business Analyst': 'empresa_tem_business_analyst',
    '3.b.10_ML Engineer/AI Engineer': 'empresa_tem_ml_engineer',
    '3.c_responsabilidades_como_gestor': 'gestor_responsabilidades_lista',
    '3.c.1_Pensar na visão de longo prazo de dados': 'gestor_resp_visao_longo_prazo',
    '3.c.2_Organização de treinamentos e iniciativas': 'gestor_resp_treinamentos',
    '3.c.3_Atração, seleção e contratação': 'gestor_resp_contratacao',
    '3.c.4_Decisão sobre contratação de ferramentas': 'gestor_resp_decisao_ferramentas',
    '3.c.5_gestor da equipe de engenharia de dados': 'gestor_resp_head_engenharia',
    '3.c.6_gestor da equipe de estudos, relatórios': 'gestor_resp_head_analise_bi',
    '3.c.7_gestor da equipe de Inteligência Artificial e Machine Learning': 'gestor_resp_head_ia_ml',
    '3.c.8_Apesar de ser gestor ainda atuo na parte técnica': 'gestor_resp_atua_tecnico',
    '3.c.9_Gestão de projetos de dados': 'gestor_resp_gestao_projetos',
    '3.c.10_Gestão de produtos de dados': 'gestor_resp_gestao_produtos',
    '3.c.11_Gestão de pessoas': 'gestor_resp_gestao_pessoas',
    '3.d.1_Contratar talentos': 'gestor_desafio_contratar_talentos',
    '3.d.2_Reter talentos': 'gestor_desafio_reter_talentos',
    '3.d.3_Convencer a empresa a aumentar investimentos': 'gestor_desafio_obter_investimento',
    '3.d.4_Gestão de equipes no ambiente remoto': 'gestor_desafio_gestao_remota',
    '3.d.5_Gestão de projetos envolvendo áreas multidisciplinares': 'gestor_desafio_projetos_multiarea',
    '3.d.6_Organizar as informações com qualidade e confiabilidade': 'gestor_desafio_qualidade_confiabilidade',
    '3.d.7_Processar e armazenar um alto volume de dados': 'gestor_desafio_volume_dados',
    '3.d.8_Gerar valor para as áreas de negócios': 'gestor_desafio_gerar_valor_negocio',
    '3.d.9_Desenvolver e manter modelos Machine Learning em produção': 'gestor_desafio_ml_em_producao',
    '3.d.10_Gerenciar a expectativa das áreas': 'gestor_desafio_gerenciar_expectativas',
    '3.d.11_Garantir a manutenção dos projetos e modelos em produção': 'gestor_desafio_manutencao_producao',
    '3.d.12_Conseguir levar inovação para a empresa': 'gestor_desafio_inovar',
    '3.d.13_Garantir (ROI) em projetos de dados': 'gestor_desafio_garantir_roi',
    '3.d.14_Dividir o tempo entre entregas técnicas e gestão': 'gestor_desafio_dividir_tempo_tecnico_gestao',
    
    # --- Tema: IA Generativa ---
    '3.f_tipo_de_uso_de_ai_generativa_e_llm_na_empresa': 'ia_uso_empresa_lista',
    '3.f.1 Colaboradores usando AI generativa de forma independente e descentralizada': 'ia_uso_empresa_independente',
    '3.f.2 Direcionamento centralizado do uso de AI generativa': 'ia_uso_empresa_centralizado',
    '3.f.3 Desenvolvedores utilizando Copilots': 'ia_uso_empresa_copilots',
    '3.f.4 AI Generativa e LLMs para melhorar produtos externos para os clientes finais': 'ia_uso_empresa_produtos_externos',
    '3.f.5 AI Generativa e LLMs para melhorar produtos internos para os colaboradores': 'ia_uso_empresa_produtos_internos',
    '3.f.6 IA Generativa e LLMs como principal frente do negócio': 'ia_uso_empresa_frente_negocio',
    '3.f.7 IA Generativa e LLMs não é prioridade': 'ia_uso_empresa_nao_prioridade',
    '3.f.8 Não sei opinar sobre o uso de IA Generativa e LLMs na empresa': 'ia_uso_empresa_nao_sabe',
    '3.g_motivos_para_não_usar_ai_generativa_e_llm': 'ia_motivos_nao_usar_lista',
    '3.g.1 Falta de compreensão dos casos de uso': 'ia_motivo_nao_uso_falta_compreensao',
    '3.g.2 Falta de confiabilidade das saídas (alucinação dos modelos)': 'ia_motivo_nao_uso_falta_confiabilidade',
    '3.g.3 Incerteza em relação a regulamentação': 'ia_motivo_nao_uso_incerteza_regulamentacao',
    '3.g.4 Preocupações com segurança e privacidade de dados': 'ia_motivo_nao_uso_seguranca_privacidade',
    '3.g.5 Retorno sobre investimento (ROI) não comprovado de IA Generativa': 'ia_motivo_nao_uso_roi_nao_comprovado',
    '3.g.6 Dados da empresa não estão prontos para uso de IA Generativa': 'ia_motivo_nao_uso_dados_nao_prontos',
    '3.g.7 Falta de expertise ou falta de recursos': 'ia_motivo_nao_uso_falta_expertise_recursos',
    '3.g.8 Alta direção da empresa não vê valor ou não vê como prioridade': 'ia_motivo_nao_uso_falta_apoio_direcao',
    '3.g.9 Preocupações com propriedade intelectual': 'ia_motivo_nao_uso_propriedade_intelectual',
    '4.m.1 Não uso soluções de AI Generativa com foco em produtividade': 'ia_uso_pessoal_nenhuma',
    '4.m.2 Uso soluções gratuitas de AI Generativa com foco em produtividade': 'ia_uso_pessoal_gratuitas',
    '4.m.3 Uso e pago pelas soluções de AI Generativa com foco em produtividade': 'ia_uso_pessoal_paga_propria',
    '4.m.4 A empresa que trabalho paga pelas soluções de AI Generativa com foco em produtividade': 'ia_uso_pessoal_empresa_paga',
    '4.m.5 Uso soluções do tipo Copilot': 'ia_uso_pessoal_copilot',

    # --- Tema: Ferramentas e Tecnologias (Detalhes) ---
    '4.a_funcao_de_atuacao': 'atuacao_funcao',
    '4.a.1_atuacao_em_dados': 'atuacao_em_dados',
    '4.b_fontes_de_dados_(dia_a_dia)': 'fontes_dados_lista',
    '4.b.1_Dados relacionais (estruturados em bancos SQL)': 'fonte_dados_usa_relacionais',
    '4.b.2_Dados armazenados em bancos NoSQL': 'fonte_dados_usa_nosql',
    '4.b.3_Imagens': 'fonte_dados_usa_imagens',
    '4.b.4_Textos/Documentos': 'fonte_dados_usa_textos',
    '4.b.5_Vídeos': 'fonte_dados_usa_videos',
    '4.b.6_Áudios': 'fonte_dados_usa_audios',
    '4.b.7_Planilhas': 'fonte_dados_usa_planilhas',
    '4.b.8_Dados georeferenciados': 'fonte_dados_usa_geo',
    '4.c_fonte_de_dado_mais_usada': 'fonte_dados_principal',
    '4.d.1_SQL': 'linguagem_usa_sql',
    '4.d.2_R': 'linguagem_usa_r',
    '4.d.3_Python': 'linguagem_usa_python',
    '4.d.4_C/C++/C#': 'linguagem_usa_c_cplusplus_csharp',
    '4.d.5_.NET': 'linguagem_usa_dotnet',
    '4.d.6_Java': 'linguagem_usa_java',
    '4.d.7_Julia': 'linguagem_usa_julia',
    '4.d.8_SAS/Stata': 'linguagem_usa_sas_stata',
    '4.d.9_Visual Basic/VBA': 'linguagem_usa_vba',
    '4.d.10_Scala': 'linguagem_usa_scala',
    '4.d.11_Matlab': 'linguagem_usa_matlab',
    '4.d.12_Rust': 'linguagem_usa_rust',
    '4.d.13_PHP': 'linguagem_usa_php',
    '4.d.14_JavaScript': 'linguagem_usa_javascript',
    '4.d.15_Não utilizo nenhuma das linguagens listadas': 'linguagem_usa_nenhuma',
    '4.g.1_MySQL': 'banco_dados_usa_mysql',
    '4.g.2_Oracle': 'banco_dados_usa_oracle',
    '4.g.3_SQL SERVER': 'banco_dados_usa_sql_server',
    '4.g.4_Amazon Aurora ou RDS': 'banco_dados_usa_aurora_rds',
    '4.g.5_DynamoDB': 'banco_dados_usa_dynamodb',
    '4.g.6_CoachDB': 'banco_dados_usa_coachdb',
    '4.g.7_Cassandra': 'banco_dados_usa_cassandra',
    '4.g.8_MongoDB': 'banco_dados_usa_mongodb',
    '4.g.9_MariaDB': 'banco_dados_usa_mariadb',
    '4.g.10_Datomic': 'banco_dados_usa_datomic',
    '4.g.11_S3': 'banco_dados_usa_s3',
    '4.g.12_PostgreSQL': 'banco_dados_usa_postgresql',
    '4.g.13_ElasticSearch': 'banco_dados_usa_elasticsearch',
    '4.g.14_DB2': 'banco_dados_usa_db2',
    '4.g.15_Microsoft Access': 'banco_dados_usa_access',
    '4.g.16_SQLite': 'banco_dados_usa_sqlite',
    '4.g.17_Sybase': 'banco_dados_usa_sybase',
    '4.g.18_Firebase': 'banco_dados_usa_firebase',
    '4.g.19_Vertica': 'banco_dados_usa_vertica',
    '4.g.20_Redis': 'banco_dados_usa_redis',
    '4.g.21_Neo4J': 'banco_dados_usa_neo4j',
    '4.g.22_Google BigQuery': 'banco_dados_usa_bigquery',
    '4.g.23_Google Firestore': 'banco_dados_usa_firestore',
    '4.g.24_Amazon Redshift': 'banco_dados_usa_redshift',
    '4.g.25_Amazon Athena': 'banco_dados_usa_athena',
    '4.g.26_Snowflake': 'banco_dados_usa_snowflake',
    '4.g.27_Databricks': 'banco_dados_usa_databricks',
    '4.g.28_HBase': 'banco_dados_usa_hbase',
    '4.g.29_Presto': 'banco_dados_usa_presto',
    '4.g.30_Splunk': 'banco_dados_usa_splunk',
    '4.g.31_SAP HANA': 'banco_dados_usa_sap_hana',
    '4.g.32_Hive': 'banco_dados_usa_hive',
    '4.g.33_Firebird': 'banco_dados_usa_firebird',
    '4.h.1_Amazon Web Services (AWS)': 'cloud_usa_aws',
    '4.h.2_Google Cloud (GCP)': 'cloud_usa_gcp',
    '4.h.3_Azure (Microsoft)': 'cloud_usa_azure',
    '4.h.4_Oracle Cloud': 'cloud_usa_oracle',
    '4.h.5_IBM': 'cloud_usa_ibm',
    '4.h.6_Servidores On Premise/Não utilizamos Cloud': 'cloud_usa_on_premise',
    '4.h.7_Cloud Própria': 'cloud_usa_propria',
    '4.j.1_Microsoft PowerBI': 'bi_usa_powerbi',
    '4.j.2_Qlik View/Qlik Sense': 'bi_usa_qlik',
    '4.j.3_Tableau': 'bi_usa_tableau',
    '4.j.4_Metabase': 'bi_usa_metabase',
    '4.j.5_Superset': 'bi_usa_superset',
    '4.j.6_Redash': 'bi_usa_redash',
    '4.j.7_Looker': 'bi_usa_looker',
    '4.j.8_Looker Studio(Google Data Studio)': 'bi_usa_looker_studio',
    '4.j.9_Amazon Quicksight': 'bi_usa_quicksight',
    '4.j.10_Alteryx': 'bi_usa_alteryx',
    '4.j.11_SAP Business Objects/SAP Analytics': 'bi_usa_sap_bi',
    '4.j.12_Oracle Business Intelligence': 'bi_usa_oracle_bi',
    '4.j.13_Salesforce/Einstein Analytics': 'bi_usa_salesforce_einstein',
    '4.j.14_SAS Visual Analytics': 'bi_usa_sas_va',
    '4.j.15_Grafana': 'bi_usa_grafana',
    '4.j.16_Pentaho': 'bi_usa_pentaho',
    '4.j.17_Fazemos todas as análises utilizando apenas Excel ou planilhas do google': 'bi_usa_excel_gsheets',
    '4.j.18_Não utilizo nenhuma ferramenta de BI no trabalho': 'bi_usa_nenhuma',
    '4.l_tipo_de_uso_de_ai_generativa_e_llm_na_empresa': 'ia_uso_empresa_lista_pessoal', # Renomeado para evitar conflito com 3.f
    
    # --- Tema: Detalhes sobre Carreiras Específicas ---
    '5.d_experiencia_em_processos_seletivos': 'carreira_experiencia_processos_seletivos',
    '6.a.1_Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.': 'de_rotina_pipeline_codigo',
    "6.a.2_Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.": 'de_rotina_etl_ferramentas',
    '6.a.3_Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.': 'de_rotina_consultas_sql',
    '6.a.4_Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.': 'de_rotina_integracao_plataformas',
    '6.a.5_Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.': 'de_rotina_modelagem_arquitetura',
    '6.a.6_Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.': 'de_rotina_manutencao_datalakes',
    '6.a.7_Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts, Datasets etc.': 'de_rotina_modelagem_dados',
    '6.a.8_Cuido da qualidade dos dados, metadados e dicionário de dados.': 'de_rotina_qualidade_dados',
    '6.a.9_Nenhuma das opções listadas refletem meu dia a dia.': 'de_rotina_nenhuma_das_opcoes',
    '6.c_possui_data_lake': 'de_empresa_possui_data_lake',
    '6.d_tecnologia_data_lake': 'de_empresa_tecnologia_data_lake',
    '6.e_possui_data_warehouse': 'de_empresa_possui_data_warehouse',
    '6.f_tecnologia_data_warehouse': 'de_empresa_tecnologia_data_warehouse',
    '6.g_ferramentas_de_qualidade_de_dados_(dia_a_dia)': 'de_ferramentas_qualidade_dados_lista',
    '6.h_maior_tempo_gasto_como_de': 'de_maior_tempo_gasto',
    '7.a.1_Processo e analiso dados utilizando linguagens de programação como Python, R etc.': 'da_rotina_analise_codigo',
    '7.a.2_Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.': 'da_rotina_dashboards_bi',
    '7.a.3_Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.': 'da_rotina_consultas_sql',
    '7.a.4_Utilizo API\\s para extrair dados e complementar minhas análises.': 'da_rotina_extracao_api',
    '7.a.5_Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.': 'da_rotina_estatistica_testes',
    '7.a.6_Desenvolvo/cuido da manutenção de ETL\\s utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.': 'da_rotina_manutencao_etl',
    '7.a.7_Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.': 'da_rotina_modelagem_dados',
    '7.a.8_Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.': 'da_rotina_manutencao_planilhas',
    '7.a.9_Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises de dados.': 'da_rotina_estatistica_avancada',
    '7.a.10_Nenhuma das opções listadas refletem meu dia a dia.': 'da_rotina_nenhuma_das_opcoes',
    '7.c_ferramentas_autonomia_area_de_negocios': 'da_ferramentas_autonomia_negocios_lista',
    '7.d_maior_tempo_gasto_como_da': 'da_maior_tempo_gasto',
    '8.a.1_Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.': 'ds_rotina_estudos_ad_hoc',
    '8.a.2_Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.': 'ds_rotina_coleta_limpeza',
    '8.a.3_Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.': 'ds_rotina_contato_negocios',
    '8.a.4_Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).': 'ds_rotina_desenvolvimento_ml',
    '8.a.5_Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.': 'ds_rotina_ml_em_producao',
    '8.a.6_Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.': 'ds_rotina_manutencao_ml',
    '8.a.7_Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc': 'ds_rotina_dashboards_bi',
    '8.a.8_Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.': 'ds_rotina_estatistica_avancada',
    '8.a.9_Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.': 'ds_rotina_manutencao_etl',
    '8.a.10_Crio e gerencio soluções de Feature Store e cultura de MLOps.': 'ds_rotina_feature_store_mlops',
    '8.a.11_Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)': 'ds_rotina_infraestrutura',
    "8.a.12_Treino e aplico LLM's para solucionar problemas de negócio.": 'ds_rotina_treino_llm',
    '8.d_maior_tempo_gasto_como_ds': 'ds_maior_tempo_gasto'
}

# %%
mapa_renomeacao_2024_restante = {
    # --- Tema: Ferramentas de ETL (Engenheiro de Dados) ---
    '6.b.1_Scripts Python': 'de_etl_scripts_python',
    '6.b.2_SQL & Stored Procedures': 'de_etl_sql_procedures',
    '6.b.3_Apache Airflow': 'de_etl_airflow',
    '6.b.4_Apache NiFi': 'de_etl_nifi',
    '6.b.5_Luigi': 'de_etl_luigi',
    '6.b.6_AWS Glue': 'de_etl_aws_glue',
    '6.b.7_Talend': 'de_etl_talend',
    '6.b.8_Pentaho': 'de_etl_pentaho',
    '6.b.9_Alteryx': 'de_etl_alteryx',
    '6.b.10_Stitch': 'de_etl_stitch',
    '6.b.11_Fivetran': 'de_etl_fivetran',
    '6.b.12_Google Dataflow': 'de_etl_google_dataflow',
    '6.b.13_Oracle Data Integrator': 'de_etl_oracle_di',
    '6.b.14_IBM DataStage': 'de_etl_ibm_datastage',
    '6.b.15_SAP BW ETL': 'de_etl_sap_bw',
    '6.b.16_SQL Server Integration Services (SSIS)': 'de_etl_ssis',
    '6.b.17_SAS Data Integration': 'de_etl_sas_di',
    '6.b.18_Qlik Sense': 'de_etl_qlik_sense',
    '6.b.19_Knime': 'de_etl_knime',
    '6.b.20_Databricks': 'de_etl_databricks',
    '6.b.21_Não utilizo ferramentas de ETL': 'de_etl_nenhuma',

    # --- Tema: Maior Tempo Gasto (Engenheiro de Dados) ---
    '6.h.1_Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.': 'de_maior_tempo_pipelines_codigo',
    '6.h.2_Realizando construções de ETL\\s em ferramentas como Pentaho, Talend, Dataflow etc.': 'de_maior_tempo_etl_ferramentas',
    '6.h.3_Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.': 'de_maior_tempo_consultas_sql',
    '6.h.4_Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.': 'de_maior_tempo_integracao_plataformas',
    '6.h.5_Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.': 'de_maior_tempo_modelagem_arquitetura',
    '6.h.6_Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.': 'de_maior_tempo_manutencao_datalakes',
    '6.h.7_Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts, Datasets etc.': 'de_maior_tempo_modelagem_dados',
    '6.h.8_Cuidando da qualidade dos dados, metadados e dicionário de dados.': 'de_maior_tempo_qualidade_dados',
    '6.h.9_Nenhuma das opções listadas refletem meu dia a dia.': 'de_maior_tempo_nenhuma_das_opcoes',

    # --- Tema: Ferramentas de ETL (Analista de Dados) ---
    '7.b.1_Scripts Python': 'da_etl_scripts_python',
    '7.b.2_SQL & Stored Procedures': 'da_etl_sql_procedures',
    '7.b.3_Apache Airflow': 'da_etl_airflow',
    '7.b.4_Apache NiFi': 'da_etl_nifi',
    '7.b.5_Luigi': 'da_etl_luigi',
    '7.b.6_AWS Glue': 'da_etl_aws_glue',
    '7.b.7_Talend': 'da_etl_talend',
    '7.b.8_Pentaho': 'da_etl_pentaho',
    '7.b.9_Alteryx': 'da_etl_alteryx',
    '7.b.10_Stitch': 'da_etl_stitch',
    '7.b.11_Fivetran': 'da_etl_fivetran',
    '7.b.12_Google Dataflow': 'da_etl_google_dataflow',
    '7.b.13_Oracle Data Integrator': 'da_etl_oracle_di',
    '7.b.14_IBM DataStage': 'da_etl_ibm_datastage',
    '7.b.15_SAP BW ETL': 'da_etl_sap_bw',
    '7.b.16_SQL Server Integration Services (SSIS)': 'da_etl_ssis',
    '7.b.17_SAS Data Integration': 'da_etl_sas_di',
    '7.b.18_Qlik Sense': 'da_etl_qlik_sense',
    '7.b.19_Knime': 'da_etl_knime',
    '7.b.20_Databricks': 'da_etl_databricks',
    '7.b.21_Não utilizo ferramentas de ETL': 'da_etl_nenhuma',

    # --- Tema: Ferramentas de Autonomia (Analista de Dados) ---
    '7.c.1_Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.': 'da_autonomia_ferramentas_automl',
    '7.c.2_"Point and Click" Analytics como Alteryx, Knime, Rapidminer etc.': 'da_autonomia_ferramentas_point_and_click',
    '7.c.3_Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.': 'da_autonomia_ferramentas_product_insights',
    '7.c.4_Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.': 'da_autonomia_ferramentas_crm_analytics',
    '7.c.5_Minha empresa não utiliza essas ferramentas.': 'da_autonomia_ferramentas_nenhuma',
    '7.c.6_Não sei informar.': 'da_autonomia_ferramentas_nao_sabe',

    # --- Tema: Maior Tempo Gasto (Analista de Dados) ---
    '7.d.1_Processando e analisando dados utilizando linguagens de programação como Python, R etc.': 'da_maior_tempo_analise_codigo',
    '7.d.2_Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.': 'da_maior_tempo_dashboards_bi',
    '7.d.3_Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.': 'da_maior_tempo_consultas_sql',
    "7.d.4_Utilizando API's para extrair dados e complementar minhas análises.": 'da_maior_tempo_extracao_api',
    '7.d.5_Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.': 'da_maior_tempo_estatistica_testes',
    "7.d.6_Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.": 'da_maior_tempo_manutencao_etl',
    '7.d.7_Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts, Datasets etc.': 'da_maior_tempo_modelagem_dados',
    '7.d.8_Desenvolvendo/cuidando da manutenção de planilhas para atender as áreas de negócio.': 'da_maior_tempo_manutencao_planilhas',
    '7.d.9_Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises de dados.': 'da_maior_tempo_estatistica_avancada',
    '7.d.10_Nenhuma das opções listadas refletem meu dia a dia.': 'da_maior_tempo_nenhuma_das_opcoes',
    
    # --- Tema: Técnicas e Métodos (Cientista de Dados) ---
    '8.b.1_Utilizo modelos de regressão (linear, logística, GLM).': 'ds_tecnica_regressao',
    '8.b.2_Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação.': 'ds_tecnica_classificacao_arvores_redes',
    '8.b.3_Desenvolvo sistemas de recomendação (RecSys).': 'ds_tecnica_sistemas_recomendacao',
    '8.b.4_Utilizo métodos estatísticos Bayesianos para analisar dados.': 'ds_tecnica_estatistica_bayesiana',
    '8.b.5_Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados.': 'ds_tecnica_nlp',
    '8.b.6_Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados.': 'ds_tecnica_estatistica_classica',
    '8.b.7_Utilizo cadeias de Markov ou HMM\\s para realizar análises de dados.': 'ds_tecnica_markov_hmm',
    '8.b.8_Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc).': 'ds_tecnica_clusterizacao',
    '8.b.9_Realizo previsões através de modelos de Séries Temporais (Time Series).': 'ds_tecnica_series_temporais',
    '8.b.10_Utilizo modelos de Reinforcement Learning (aprendizado por reforço).': 'ds_tecnica_reinforcement_learning',
    '8.b.11_Utilizo modelos de Machine Learning para detecção de fraude.': 'ds_tecnica_deteccao_fraude',
    '8.b.12_Utilizo métodos de Visão Computacional.': 'ds_tecnica_visao_computacional',
    '8.b.13_Utilizo modelos de Detecção de Churn.': 'ds_tecnica_deteccao_churn',
    "8.b.14_Utilizo LLM's para solucionar problemas de negócio.": 'ds_tecnica_llm',

    # --- Tema: Tecnologias (Cientista de Dados) ---
    '8.c.1_Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc).': 'ds_tecnologia_ferramentas_bi',
    '8.c.2_Planilhas (Excel, Google Sheets etc).': 'ds_tecnologia_planilhas',
    '8.c.3_Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda).': 'ds_tecnologia_dev_local',
    '8.c.4_Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc).': 'ds_tecnologia_dev_nuvem',
    '8.c.5_Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc).': 'ds_tecnologia_automl',
    '8.c.6_Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc).': 'ds_tecnologia_etl',
    '8.c.7_Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc).': 'ds_tecnologia_plataformas_ml',
    '8.c.8_Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc).': 'ds_tecnologia_feature_store',
    '8.c.9_Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc).': 'ds_tecnologia_controle_versao',
    '8.c.10_Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc).': 'ds_tecnologia_data_apps',
    '8.c.11_Ferramentas de estatística avançada como SPSS, SAS, etc.': 'ds_tecnologia_estatistica_avancada',
    
    # --- Tema: Maior Tempo Gasto (Cientista de Dados) ---
    '8.d.1_Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.': 'ds_maior_tempo_estudos_ad_hoc',
    '8.d.2_Coletando e limpando dos dados que uso para análise e modelagem.': 'ds_maior_tempo_coleta_limpeza',
    '8.d.3_Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.': 'ds_maior_tempo_contato_negocios',
    '8.d.4_Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).': 'ds_maior_tempo_desenvolvimento_ml',
    '8.d.5_Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.': 'ds_maior_tempo_ml_em_producao',
    '8.d.6_Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.': 'ds_maior_tempo_manutencao_ml',
    '8.d.7_Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.': 'ds_maior_tempo_dashboards_bi',
    '8.d.8_Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.': 'ds_maior_tempo_estatistica_avancada',
    '8.d.9_Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.': 'ds_maior_tempo_manutencao_etl',
    '8.d.10_Criando e gerenciando soluções de Feature Store e cultura de MLOps.': 'ds_maior_tempo_feature_store_mlops',
    '8.d.11_Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)': 'ds_maior_tempo_infraestrutura',
    "8.d.12_Treinando e aplicando LLM's para solucionar problemas de negócio.": 'ds_maior_tempo_treino_llm'
}

# %%
print(len(mapa_renomeacao_2024))
print(len(mapa_renomeacao_2024_restante))
print(f'A soma dos dicionários é {len(mapa_renomeacao_2024) + len(mapa_renomeacao_2024_restante)} e o total do dataset é {len(df_2024_kaggle.columns)}')
# Out:
# 287
# 104
# A soma dos dicionários é 391 e o total do dataset é 423

# %% [markdown]
# # renomeação dos dicionários:

# %%
mapa_final_2024 = {**mapa_renomeacao_2024, **mapa_renomeacao_2024_restante}
print(f"O dicionário final e completo tem {len(mapa_final_2024)} colunas para renomear.")
# Out:
# O dicionário final e completo tem 391 colunas para renomear.

# %%
df_2024_kaggle_renomeado = df_2024_kaggle.rename(columns=mapa_final_2024)

# %%
len(df_2024_kaggle_renomeado.columns.tolist())
# Out:
# 423

# %%
print(df_2024_kaggle_renomeado.columns.tolist())
# Out:
# ['id_participante', 'data_envio', 'idade', 'faixa_idade', 'genero', 'etnia', 'pcd', 'experiencia_prejudicada', 'prejudicado_acredita_nao_ser_afetado', 'prejudicado_raca_etnia', 'prejudicado_genero', 'prejudicado_pcd', 'uf_residencia', 'prejudicado_aspecto_qtd_oportunidades', 'prejudicado_aspecto_senioridade_vagas', 'prejudicado_aspecto_aprovacao_processos', 'prejudicado_aspecto_oportunidade_progressao', 'prejudicado_aspecto_velocidade_progressao', 'prejudicado_aspecto_cobranca_stress', 'prejudicado_aspecto_atencao_ideias', 'prejudicado_aspecto_relacao_trabalho', 'prejudicado_aspecto_relacao_integracao', 'regiao_residencia', 'prejudicado_aspectos_lista', 'uf_origem', 'regiao_origem', 'vive_no_brasil', 'pais_residencia', 'estado_residencia', 'vive_no_estado_formacao', 'estado_origem', 'nivel_ensino', 'area_formacao', 'situacao_trabalho', 'setor_atuacao', 'tamanho_empresa', 'atua_como_gestor', 'cargo_gestor', 'cargo_atual', 'nivel_hierarquico', 'faixa_salarial', 'experiencia_dados_anos'
# ...

# %%
output_path = PROCESSED_DATA_DIR / 'state_of_data_2024_rico_limpo.csv'
df_2024_kaggle_renomeado.to_csv(output_path, index=False)
