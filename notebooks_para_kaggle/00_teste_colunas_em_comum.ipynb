# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys

sys.path.append('../src')
import data_cleaner as dc

# %%
RAW_DATA_DIR, PROCESSED_DATA_DIR = dc.caminho_para_dataset()

# %%
try:
  df_2024_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2024_rico_limpo.csv')
  df_2023_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2023_rico_limpo.csv')
  df_2022_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2022_rico_limpo.csv')
  df_2021_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2021_rico_limpo.csv')
  print('arquivos encontrados')
except FileNotFoundError as e: 
  print("Arquivo nao encontrado " + e)
# Out:
# arquivos encontrados
# /tmp/ipykernel_37759/1234047827.py:5: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2021_rico_limpo.csv')

# %%
colunas_2024 = set(df_2024_kaggle)
colunas_2023 = set(df_2023_kaggle)
colunas_2022 = set(df_2022_kaggle)
colunas_2021 = set(df_2021_kaggle)

colunas_comum = colunas_2024.intersection(colunas_2023, colunas_2022, colunas_2021)

# %%
len(colunas_comum)
# Out:
# 290

# %%
colunas_so_em_2024 = colunas_2024 - colunas_2023 - colunas_2022 - colunas_2021
colunas_so_em_2023 = colunas_2023 - colunas_2024 - colunas_2022 - colunas_2021
colunas_so_em_2022 = colunas_2022 - colunas_2023 - colunas_2024 - colunas_2021
colunas_so_em_2021 = colunas_2021 - colunas_2022 - colunas_2023 - colunas_2024

# %%
print(f"Total de colunas em 2024: {len(colunas_2024)}")
print(f"Total de colunas em 2023: {len(colunas_2023)}")
print(f"Total de colunas em 2022: {len(colunas_2022)}")
print(f"Total de colunas em 2022: {len(colunas_2021)}")

print("-" * 50)
print(f"Colunas em comum: {len(colunas_comum)}")
print(f"Colunas exclusivas de 2024: {len(colunas_so_em_2024)}")
print(f"Colunas exclusivas de 2023: {len(colunas_so_em_2023)}")
print(f"Colunas exclusivas de 2022: {len(colunas_so_em_2022)}")
print(f"Colunas exclusivas de 2021: {len(colunas_so_em_2021)}")

print("-" * 50)
# Out:
# Total de colunas em 2024: 423
# Total de colunas em 2023: 403
# Total de colunas em 2022: 357
# Total de colunas em 2022: 360
# --------------------------------------------------
# Colunas em comum: 290
# Colunas exclusivas de 2024: 59
# Colunas exclusivas de 2023: 12
# Colunas exclusivas de 2022: 13
# Colunas exclusivas de 2021: 36
# --------------------------------------------------

# %%
print("Exclusivas de 2024:", sorted(list(colunas_so_em_2024)))
print("Exclusivas de 2023:", sorted(list(colunas_so_em_2023)))
print("Exclusivas de 2022:", sorted(list(colunas_so_em_2022)))
print("Exclusivas de 2021:", sorted(list(colunas_so_em_2021)))
# Out:
# Exclusivas de 2024: ['4.c.1_Dados relacionais (estruturados em bancos SQL)', '4.c.2_Dados armazenados em bancos NoSQL', '4.c.3_Imagens', '4.c.4_Textos/Documentos', '4.c.5_Vídeos', '4.c.6_Áudios', '4.c.7_Planilhas', '4.c.8_Dados georeferenciados', '4.l.1 Colaboradores usando AI generativa de forma independente e descentralizada', '4.l.2 Direcionamento centralizado do uso de AI generativa', '4.l.3 Desenvolvedores utilizando Copilots', '4.l.4 AI Generativa e LLMs para melhorar produtos externos para os clientes finais', '4.l.5 AI Generativa e LLMs para melhorar produtos internos para os colaboradores', '4.l.6 IA Generativa e LLMs como principal frente do negócio', '4.l.7 IA Generativa e LLMs não é prioridade', '4.l.8 Não sei opinar sobre o uso de IA Generativa e LLMs na empresa', 'data_envio', 'empresa_tem_ml_engineer', 'estado_origem', 'ferramentas_etl_analyst', 'ferramentas_etl_engineer', 'pais_residencia', 'prejudicado_genero', 'prejudicado_pcd', 'prejudicado_raca_etnia', 'rotina_analista_dados', 'rotina_cientista_dados', 'rotina_engenheiro_dados', 'satisfacao_fator_ambiente', 'satisfacao_fator_aprendizado', 'satisfacao_fator_beneficios', 'satisfacao_fator_crescimento', 'satisfacao_fator_desejo_mudar_area', 'satisfacao_fator_flexibilidade', 'satisfacao_fator_maturidade_empresa', 'satisfacao_fator_proposito', 'satisfacao_fator_relacao_gestores', 'satisfacao_fator_remuneracao', 'satisfacao_fator_reputacao_empresa', 'tecnicas_ml_cientista', 'tecnologias_cientista', 'uf_origem', 'usa_.net', 'usa_c_c++_c#', 'usa_java', 'usa_javascript', 'usa_julia', 'usa_matlab', 'usa_nenhuma', 'usa_não_utilizo_linguagem_de_programação_no_trabalho', 'usa_php', 'usa_python', 'usa_r', 'usa_rust', 'usa_sas_stata', 'usa_scala', 'usa_sql', 'usa_visual_basic_vba', 'vive_no_estado_formacao']
# Exclusivas de 2023: ['cloud_preferida_lista', 'ia_uso_empresa_centralizado.1', 'ia_uso_empresa_copilots.1', 'ia_uso_empresa_frente_negocio.1', 'ia_uso_empresa_independente.1', 'ia_uso_empresa_nao_prioridade.1', 'ia_uso_empresa_nao_sabe.1', 'ia_uso_empresa_produtos_externos.1', 'ia_uso_empresa_produtos_internos.1', 'prejudicado_motivo_genero', 'prejudicado_motivo_pcd', 'prejudicado_motivo_raca_etnia']
# Exclusivas de 2022: ['de_qualidade_acceldata', 'de_qualidade_amundsen', 'de_qualidade_anomalo', 'de_qualidade_apache_griffin', 'de_qualidade_aws_deequ', 'de_qualidade_big_eye', 'de_qualidade_data_band', 'de_qualidade_datafold', 'de_qualidade_dbt', 'de_qualidade_great_expectations', 'de_qualidade_metaplane', 'de_qualidade_monte_carlo', 'de_qualidade_soda']
# Exclusivas de 2021: ['banco_dados_usa_sap', 'de_qualidade_dados_acceldata', 'de_qualidade_dados_amundsen', 'de_qualidade_dados_anomalo', 'de_qualidade_dados_apache_griffin', 'de_qualidade_dados_aws_deequ', 'de_qualidade_dados_big_eye', 'de_qualidade_dados_data_band', 'de_qualidade_dados_datafold', 'de_qualidade_dados_dbt', 'de_qualidade_dados_great_expectations', 'de_qualidade_dados_metaplane', 'de_qualidade_dados_monte_carlo', 'de_qualidade_dados_soda', 'dh_iniciativa_blog', 'dh_iniciativa_nao_conhecia', 'dh_iniciativa_newsletter', 'dh_iniciativa_podcast', 'dh_iniciativa_slack', 'dh_iniciativa_youtube', 'dh_iniciativas_acessadas_lista', 'ds_tecnologia_nenhuma', 'linguagem_principal_c_cplusplus_csharp', 'linguagem_principal_dotnet', 'linguagem_principal_java', 'linguagem_principal_javascript', 'linguagem_principal_julia', 'linguagem_principal_matlab', 'linguagem_principal_nenhuma', 'linguagem_principal_php', 'linguagem_principal_python', 'linguagem_principal_r', 'linguagem_principal_sas_stata', 'linguagem_principal_scala', 'linguagem_principal_sql', 'linguagem_principal_vba']

# %%
df_unificado = pd.concat([df_2024_kaggle, df_2023_kaggle, df_2022_kaggle, df_2021_kaggle], ignore_index=True, sort=False)

# %%
print("União concluída com sucesso!")
print(f"Dimensões do DataFrame unificado: {df_unificado.shape}")
print('\nTeste de coluna')
print(df_unificado['ano'].value_counts())
# Out:
# União concluída com sucesso!
# Dimensões do DataFrame unificado: (17426, 513)
#
# Teste de coluna
# ano
# 2023    5293
# 2024    5217
# 2022    4271
# 2021    2645
# Name: count, dtype: int64

# %%
df_unificado
# Out:
#                         id_participante           data_envio  idade  \
# 0      reb94rv0msth7q4nreb94riaq80iz3yi  2024-10-16 11:19:17   18.0
# 1      1zc66g69jjt49y32l1zc66g8wqj79m4e  2024-10-16 20:45:31   18.0
# 2      uu99wmam4n5kc2uu99wmydf0rk7l58f7  2024-10-17 18:10:59   18.0
# 3      3ynsw7z0hl5hhpbfvaeqk73ynsw7z04l  2024-10-22 18:03:00   18.0
# 4      v6bji2ct5xckpl1uouv6bjiotkrf3b4f  2024-10-23 01:33:23   18.0
# ...                                 ...                  ...    ...
# 17421  07nvo8cdy377a46gon207nvjebwe65zg                  NaN   40.0
# 17422  01mqnby32u01pg3nuj6vipp4mc06s8pg                  NaN   27.0
# 17423  01fncs8qbhl9zx01fncs8rqib2zl3d18                  NaN   24.0
# 17424  075h3v2z19if04yn7o075h3vhifl38rw                  NaN   38.0
# 17425  037usz1h2yip96dgil4mhj037uszw1gk                  NaN   27.0
#
#       faixa_idade     genero   etnia  pcd  \
# 0           17-21  Masculino  Branca  Não
# 1           17-21  Masculino  Branca  Não
# 2           17-21  Masculino   Parda  Não
# 3           17-21  Masculino  Branca  Não
# 4           17-21  Masculino  Branca  Não
# ...           ...        ...     ...  ...
# 17421       40-44  Masculino     NaN  NaN
# 17422       25-29  Masculino     NaN  NaN
# 17423       22-24  Masculino     NaN  NaN
# 17424       35-39  Masculino     NaN  NaN
# 17425       25-29   Feminino     NaN  NaN
#
#                                  experiencia_prejudicada  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Não acredito que minha experiência profissiona...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17421                                                NaN
# 17422                                                NaN
# 17423                                                NaN
# 17424                                                NaN
# 17425                                                NaN
#
#        prejudicado_acredita_nao_ser_afetado  prejudicado_raca_etnia  ...  \
# 0                                       NaN                     NaN  ...
# 1                                       NaN                     NaN  ...
# 2                                       1.0                     0.0  ...
# 3                                       NaN                     NaN  ...
# 4                                       NaN                     NaN  ...
# ...                                     ...                     ...  ...
# 17421                                   NaN                     NaN  ...
# 17422                                   NaN                     NaN  ...
# 17423                                   NaN                     NaN  ...
# 17424                                   NaN                     NaN  ...
# 17425                                   NaN                     NaN  ...
#
#        de_qualidade_dados_metaplane  de_qualidade_dados_acceldata  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 17421                           NaN                           NaN
# 17422                           NaN                           NaN
# 17423                           NaN                           NaN
# 17424                           NaN                           NaN
# 17425                           NaN                           NaN
#
#       ds_tecnologia_nenhuma  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 17421                   NaN
# 17422                   0.0
# 17423                   NaN
# 17424                   NaN
# 17425                   NaN
#
#                           dh_iniciativas_acessadas_lista  dh_iniciativa_blog  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 17421                  Ainda não conhecia o Data Hackers                 0.0
# 17422                        Blog/Medium do Data Hackers                 1.0
# 17423  Blog/Medium do Data Hackers, Podcast do Data H...                 1.0
# 17424                        Blog/Medium do Data Hackers                 1.0
# 17425                  Ainda não conhecia o Data Hackers                 0.0
#
#        dh_iniciativa_podcast  dh_iniciativa_newsletter  dh_iniciativa_slack  \
# 0                        NaN                       NaN                  NaN
# 1                        NaN                       NaN                  NaN
# 2                        NaN                       NaN                  NaN
# 3                        NaN                       NaN                  NaN
# 4                        NaN                       NaN                  NaN
# ...                      ...                       ...                  ...
# 17421                    0.0                       0.0                  0.0
# 17422                    0.0                       0.0                  0.0
# 17423                    1.0                       1.0                  1.0
# 17424                    0.0                       0.0                  0.0
# 17425                    0.0                       0.0                  0.0
#
#        dh_iniciativa_youtube  dh_iniciativa_nao_conhecia
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ...                      ...                         ...
# 17421                    0.0                         1.0
# 17422                    0.0                         0.0
# 17423                    0.0                         0.0
# 17424                    0.0                         0.0
# 17425                    0.0                         1.0
#
# [17426 rows x 513 columns]

# %%
output_path = PROCESSED_DATA_DIR / 'state_of_data_unificado.csv'
df_unificado.to_csv(output_path, index=False)
