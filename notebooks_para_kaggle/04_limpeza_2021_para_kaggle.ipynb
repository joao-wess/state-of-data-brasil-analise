# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys

sys.path.append('../src')
import data_cleaner as dc

# %%
RAW_DATA_DIR, PROCESSED_DATA_DIR = dc.caminho_para_dataset()

# %%
try:
  df_2021_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2021_limpo.csv')
  print('arquivo encontrado')
except FileNotFoundError as e: 
  print("Arquivo nao encontrado " + e)
# Out:
# arquivo encontrado
# /tmp/ipykernel_38245/509723685.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021_kaggle = pd.read_csv (PROCESSED_DATA_DIR / 'state_of_data_2021_limpo.csv')

# %%
print(df_2021_kaggle.columns.tolist())
# Out:
# ['id_participante', 'idade', 'faixa_idade', 'genero', "('P1_e ', 'Estado onde mora')", 'uf_residencia', 'regiao_residencia', 'regiao_origem', "('P1_g_c ', 'Mudou de Estado?')", 'nivel_ensino', 'area_formacao', 'situacao_trabalho', 'setor_atuacao', 'tamanho_empresa', 'atua_como_gestor', "('P2_e ', 'Cargo como Gestor')", 'cargo_atual', 'nivel_hierarquico', 'faixa_salarial', 'experiencia_dados_anos', 'experiencia_ti_anos', 'satisfacao_trabalho', 'motivos_insatisfacao', "('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')", "('P2_l_b ', 'Salário atual não corresponde ao mercado')", "('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')", "('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')", "('P2_l_e ', 'Gostaria de receber mais benefícios')", "('P2_l_f ', 'O clima de trabalho/ambiente não é bom')", "('P2_l_g ', 'Falta de maturidade analítica na empresa')", 'entrevistas_ultimos_6m', 'planos_mudar_emprego', 'criterios_escolha_emprego', "('P2_o_a ', '
# ...

# %%
len(df_2021_kaggle.columns)
# Out:
# 360

# %%
mapa_renomeacao_2021 = {
    # === Colunas que você já mapeou (mantidas e validadas) ===
    'id_participante': 'id_participante', 'idade': 'idade', 'faixa_idade': 'faixa_idade', 'genero': 'genero', 'uf_residencia': 'uf_residencia', 'regiao_residencia': 'regiao_residencia', 'regiao_origem': 'regiao_origem', 'nivel_ensino': 'nivel_ensino', 'area_formacao': 'area_formacao', 'situacao_trabalho': 'situacao_trabalho', 'setor_atuacao': 'setor_atuacao', 'tamanho_empresa': 'tamanho_empresa', 'atua_como_gestor': 'atua_como_gestor', 'cargo_atual': 'cargo_atual', 'nivel_hierarquico': 'nivel_hierarquico', 'faixa_salarial': 'faixa_salarial', 'experiencia_dados_anos': 'experiencia_dados_anos', 'experiencia_ti_anos': 'experiencia_ti_anos', 'satisfacao_trabalho': 'satisfacao_trabalho', 'motivos_insatisfacao': 'motivos_insatisfacao', 'entrevistas_ultimos_6m': 'entrevistas_ultimos_6m', 'planos_mudar_emprego': 'planos_mudar_emprego', 'criterios_escolha_emprego': 'criterios_escolha_emprego', 'modelo_trabalho_atual': 'modelo_trabalho_atual', 'modelo_trabalho_ideal': 'modelo_trabalho_ideal', 'tamanho_equipe_dados': 'tamanho_equipe_dados', 'desafios_gestor': 'desafios_gestor', 'linguagens_usadas_dia_a_dia': 'linguagens_usadas_dia_a_dia', 'linguagem_principal': 'linguagem_principal', 'bancos_dados_usados_dia_a_dia': 'bancos_dados_usados_dia_a_dia', 'clouds_utilizadas': 'clouds_utilizadas', 'ferramentas_bi_usadas_dia_a_dia': 'ferramentas_bi_usadas_dia_a_dia', 'tipo_oportunidade_buscada': 'tipo_oportunidade_buscada', 'tempo_busca_emprego_meses': 'tempo_busca_emprego_meses', 'salario_medio_mensal': 'salario_medio_mensal', 'grupo_cargo': 'grupo_cargo', 'experiencia_anos_num': 'experiencia_anos_num', 'ano': 'ano',

    # === NOVAS COLUNAS MAPEADAS (COMPLEMENTO) ===

    # --- Tema: Demografia Adicional ---
    "('P1_e ', 'Estado onde mora')": 'estado_residencia',
    "('P1_g_c ', 'Mudou de Estado?')": 'mudou_de_estado',

    # --- Tema: Detalhes do Trabalho ---
    "('P2_e ', 'Cargo como Gestor')": 'cargo_gestor',
    "('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')": 'atitude_retorno_presencial',

    # --- Tema: Motivos de Insatisfação e Critérios de Escolha ---
    "('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')": 'insatisfacao_fator_falta_crescimento',
    "('P2_l_b ', 'Salário atual não corresponde ao mercado')": 'insatisfacao_fator_salario_defasado',
    "('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')": 'insatisfacao_fator_relacao_gestor',
    "('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')": 'insatisfacao_fator_desejo_mudar_area',
    "('P2_l_e ', 'Gostaria de receber mais benefícios')": 'insatisfacao_fator_beneficios',
    "('P2_l_f ', 'O clima de trabalho/ambiente não é bom')": 'insatisfacao_fator_ambiente_ruim',
    "('P2_l_g ', 'Falta de maturidade analítica na empresa')": 'insatisfacao_fator_baixa_maturidade_empresa',
    "('P2_o_a ', 'Remuneração/Salário')": 'criterio_escolha_remuneracao',
    "('P2_o_b ', 'Benefícios')": 'criterio_escolha_beneficios',
    "('P2_o_c ', 'Propósito do trabalho e da empresa')": 'criterio_escolha_proposito',
    "('P2_o_d ', 'Flexibilidade de trabalho remoto')": 'criterio_escolha_flexibilidade',
    "('P2_o_e ', 'Ambiente e clima de trabalho')": 'criterio_escolha_ambiente',
    "('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')": 'criterio_escolha_aprendizado',
    "('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')": 'criterio_escolha_plano_carreira',
    "('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')": 'criterio_escolha_maturidade_empresa',
    "('P2_o_i ', 'Qualidade dos gestores e líderes')": 'criterio_escolha_qualidade_gestores',
    "('P2_o_j ', 'Reputação que a empresa tem no mercado')": 'criterio_escolha_reputacao_empresa',

    # --- Tema: Detalhes da Equipe de Dados e Gestão ---
    "('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')": 'empresa_cargos_dados_lista',
    "('P3_b_a ', 'Analytics Engineer')": 'empresa_tem_analytics_engineer',
    "('P3_b_b ', 'Engenharia de Dados/Data Engineer')": 'empresa_tem_engenheiro_dados',
    "('P3_b_c ', 'Analista de Dados/Data Analyst')": 'empresa_tem_analista_dados',
    "('P3_b_d ', 'Cientista de Dados/Data Scientist')": 'empresa_tem_cientista_dados',
    "('P3_b_e ', 'Database Administrator/DBA')": 'empresa_tem_dba',
    "('P3_b_f ', 'Analista de Business Intelligence/BI')": 'empresa_tem_analista_bi',
    "('P3_b_g ', 'Arquiteto de Dados/Data Architect')": 'empresa_tem_arquiteto_dados',
    "('P3_b_h ', 'Data Product Manager/DPM')": 'empresa_tem_dpm',
    "('P3_b_i ', 'Business Analyst')": 'empresa_tem_business_analyst',
    "('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')": 'gestor_responsabilidades_lista',
    "('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')": 'gestor_resp_visao_longo_prazo',
    "('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')": 'gestor_resp_treinamentos',
    "('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')": 'gestor_resp_contratacao',
    "('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')": 'gestor_resp_decisao_ferramentas',
    "('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')": 'gestor_resp_head_engenharia',
    "('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')": 'gestor_resp_head_analise_bi',
    "('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')": 'gestor_resp_head_ia_ml',
    "('P3_c_h ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')": 'gestor_resp_atua_tecnico',
    "('P3_c_i ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')": 'gestor_resp_gestao_projetos',
    "('P3_c_j ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')": 'gestor_resp_gestao_produtos',
    "('P3_c_k ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')": 'gestor_resp_gestao_pessoas',
    "('P3_d_ ', 'a Contratar novos talentos.')": 'gestor_desafio_contratar_talentos',
    "('P3_d_ ', 'b Reter talentos.')": 'gestor_desafio_reter_talentos',
    "('P3_d_ ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')": 'gestor_desafio_obter_investimento',
    "('P3_d_ ', 'd Gestão de equipes no ambiente remoto.')": 'gestor_desafio_gestao_remota',
    "('P3_d_ ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')": 'gestor_desafio_projetos_multiarea',
    "('P3_d_ ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')": 'gestor_desafio_qualidade_confiabilidade',
    "('P3_d_ ', 'g Conseguir processar e armazenar um alto volume de dados.')": 'gestor_desafio_volume_dados',
    "('P3_d_ ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')": 'gestor_desafio_gerar_valor_negocio',
    "('P3_d_ ', 'i Desenvolver e manter modelos Machine Learning em produção.')": 'gestor_desafio_ml_em_producao',
    "('P3_d_ ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')": 'gestor_desafio_gerenciar_expectativas',
    "('P3_d_ ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')": 'gestor_desafio_manutencao_producao',
    "('P3_d_l ', 'Conseguir levar inovação para a empresa através dos dados.')": 'gestor_desafio_inovar',
    "('P3_d_m ', 'Garantir retorno do investimento (ROI) em projetos de dados.')": 'gestor_desafio_garantir_roi',
    "('P3_d_n ', 'Dividir o tempo entre entregas técnicas e gestão.')": 'gestor_desafio_dividir_tempo_tecnico_gestao',

    # --- Tema: Ferramentas e Tecnologias (Detalhes) ---
    "('P4_a_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')": 'atuacao_funcao',
    "('P4_a ', 'Atuacao')": 'atuacao_em_dados',
    "('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')": 'fontes_dados_lista',
    "('P4_b_a ', 'Dados relacionais (estruturados em bancos SQL)')": 'fonte_dados_usa_relacionais',
    "('P4_b_b ', 'Dados armazenados em bancos NoSQL')": 'fonte_dados_usa_nosql',
    "('P4_b_c ', 'Imagens')": 'fonte_dados_usa_imagens',
    "('P4_b_d ', 'Textos/Documentos')": 'fonte_dados_usa_textos',
    "('P4_b_e ', 'Vídeos')": 'fonte_dados_usa_videos',
    "('P4_b_f ', 'Áudios')": 'fonte_dados_usa_audios',
    "('P4_b_g ', 'Planilhas')": 'fonte_dados_usa_planilhas',
    "('P4_b_h ', 'Dados georeferenciados')": 'fonte_dados_usa_geo',
    "('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')": 'fonte_dados_principal',
    "('P4_c_a ', 'Dados relacionais (estruturados em bancos SQL)')": 'fonte_dados_principal_relacionais',
    "('P4_c_b ', 'Dados armazenados em bancos NoSQL')": 'fonte_dados_principal_nosql',
    "('P4_c_c ', 'Imagens')": 'fonte_dados_principal_imagens',
    "('P4_c_d ', 'Textos/Documentos')": 'fonte_dados_principal_textos',
    "('P4_c_e ', 'Vídeos')": 'fonte_dados_principal_videos',
    "('P4_c_f ', 'Áudios')": 'fonte_dados_principal_audios',
    "('P4_c_g ', 'Planilhas')": 'fonte_dados_principal_planilhas',
    "('P4_c_h ', 'Dados georeferenciados')": 'fonte_dados_principal_geo',
    "('P4_d_a ', 'SQL')": 'linguagem_usa_sql',
    "('P4_d_b ', 'R ')": 'linguagem_usa_r',
    "('P4_d_c ', 'Python')": 'linguagem_usa_python',
    "('P4_d_d ', 'C/C++/C#')": 'linguagem_usa_c_cplusplus_csharp',
    "('P4_d_e ', '.NET')": 'linguagem_usa_dotnet',
    "('P4_d_f ', 'Java')": 'linguagem_usa_java',
    "('P4_d_g ', 'Julia')": 'linguagem_usa_julia',
    "('P4_d_h ', 'SAS/Stata')": 'linguagem_usa_sas_stata',
    "('P4_d_i ', 'Visual Basic/VBA')": 'linguagem_usa_vba',
    "('P4_d_j ', 'Scala')": 'linguagem_usa_scala',
    "('P4_d_k ', 'Matlab')": 'linguagem_usa_matlab',
    "('P4_d_l ', 'PHP')": 'linguagem_usa_php',
    "('P4_d_m ', 'Javascript')": 'linguagem_usa_javascript',
    "('P4_d_n ', 'Não utilizo nenhuma linguagem')": 'linguagem_usa_nenhuma',
    "('P4_e_a ', 'SQL')": 'linguagem_principal_sql',
    "('P4_e_b ', 'R ')": 'linguagem_principal_r',
    "('P4_e_c ', 'Python')": 'linguagem_principal_python',
    "('P4_e_d ', 'C/C++/C#')": 'linguagem_principal_c_cplusplus_csharp',
    "('P4_e_e ', '.NET')": 'linguagem_principal_dotnet',
    "('P4_e_f ', 'Java')": 'linguagem_principal_java',
    "('P4_e_g ', 'Julia')": 'linguagem_principal_julia',
    "('P4_e_h ', 'SAS/Stata')": 'linguagem_principal_sas_stata',
    "('P4_e_i ', 'Visual Basic/VBA')": 'linguagem_principal_vba',
    "('P4_e_j ', 'Scala')": 'linguagem_principal_scala',
    "('P4_e_k ', 'Matlab')": 'linguagem_principal_matlab',
    "('P4_e_l ', 'PHP')": 'linguagem_principal_php',
    "('P4_e_m ', 'Javascript')": 'linguagem_principal_javascript',
    "('P4_e_n ', 'Não utilizo nenhuma linguagem')": 'linguagem_principal_nenhuma',
    "('P4_f_a ', 'MySQL')": 'banco_dados_usa_mysql',
    "('P4_f_b ', 'Oracle')": 'banco_dados_usa_oracle',
    "('P4_f_c ', 'SQL SERVER')": 'banco_dados_usa_sql_server',
    "('P4_f_d ', 'SAP')": 'banco_dados_usa_sap',
    "('P4_f_e ', 'Amazon Aurora ou RDS')": 'banco_dados_usa_aurora_rds',
    "('P4_f_f ', 'Amazon DynamoDB')": 'banco_dados_usa_dynamodb',
    "('P4_f_g ', 'CoachDB')": 'banco_dados_usa_coachdb',
    "('P4_f_h ', 'Cassandra')": 'banco_dados_usa_cassandra',
    "('P4_f_i ', 'MongoDB')": 'banco_dados_usa_mongodb',
    "('P4_f_j ', 'MariaDB')": 'banco_dados_usa_mariadb',
    "('P4_f_k ', 'Datomic')": 'banco_dados_usa_datomic',
    "('P4_f_l ', 'S3')": 'banco_dados_usa_s3',
    "('P4_f_m ', 'PostgreSQL')": 'banco_dados_usa_postgresql',
    "('P4_f_n ', 'ElasticSearch')": 'banco_dados_usa_elasticsearch',
    "('P4_f_o ', 'DB2')": 'banco_dados_usa_db2',
    "('P4_f_p ', 'Microsoft Access')": 'banco_dados_usa_access',
    "('P4_f_q ', 'SQLite')": 'banco_dados_usa_sqlite',
    "('P4_f_r ', 'Sybase')": 'banco_dados_usa_sybase',
    "('P4_f_s ', 'Firebase')": 'banco_dados_usa_firebase',
    "('P4_f_t ', 'Vertica')": 'banco_dados_usa_vertica',
    "('P4_f_u ', 'Redis')": 'banco_dados_usa_redis',
    "('P4_f_v ', 'Neo4J')": 'banco_dados_usa_neo4j',
    "('P4_f_x ', 'Google BigQuery')": 'banco_dados_usa_bigquery',
    "('P4_f_y ', 'Google Firestore')": 'banco_dados_usa_firestore',
    "('P4_f_z ', 'Amazon Redshift')": 'banco_dados_usa_redshift',
    "('P4_f_z1 ', 'Amazon Athena')": 'banco_dados_usa_athena',
    "('P4_f_z2 ', 'Snowflake')": 'banco_dados_usa_snowflake',
    "('P4_f_z3 ', 'Databricks')": 'banco_dados_usa_databricks',
    "('P4_f_z4 ', 'HBase')": 'banco_dados_usa_hbase',
    "('P4_f_z5 ', 'Presto')": 'banco_dados_usa_presto',
    "('P4_f_z6 ', 'Splunk')": 'banco_dados_usa_splunk',
    "('P4_f_z7 ', 'SAP HANA')": 'banco_dados_usa_sap_hana',
    "('P4_f_z8 ', 'Hive')": 'banco_dados_usa_hive',
    "('P4_f_z9 ', 'Firebird')": 'banco_dados_usa_firebird',
    "('P4_g_a ', 'Amazon Web Services (AWS)')": 'cloud_usa_aws',
    "('P4_g_b ', 'Google Cloud (GCP)')": 'cloud_usa_gcp',
    "('P4_g_c ', 'Azure (Microsoft)')": 'cloud_usa_azure',
    "('P4_g_d ', 'Oracle Cloud')": 'cloud_usa_oracle',
    "('P4_g_e ', 'IBM')": 'cloud_usa_ibm',
    "('P4_g_f ', 'Servidores On Premise/Não utilizamos Cloud')": 'cloud_usa_on_premise',
    "('P4_g_g ', 'Cloud Própria')": 'cloud_usa_propria',
    "('P4_h_a ', 'Microsoft PowerBI')": 'bi_usa_powerbi',
    "('P4_h_b ', 'Qlik View/Qlik Sense')": 'bi_usa_qlik',
    "('P4_h_c ', 'Tableau')": 'bi_usa_tableau',
    "('P4_h_d ', 'Metabase')": 'bi_usa_metabase',
    "('P4_h_e ', 'Superset')": 'bi_usa_superset',
    "('P4_h_f ', 'Redash')": 'bi_usa_redash',
    "('P4_h_g ', 'MicroStrategy')": 'bi_usa_microstrategy',
    "('P4_h_h ', 'IBM Analytics/Cognos')": 'bi_usa_ibm_cognos',
    "('P4_h_i ', 'SAP Business Objects')": 'bi_usa_sap_bi',
    "('P4_h_j ', 'Oracle Business Intelligence')": 'bi_usa_oracle_bi',
    "('P4_h_k ', 'Amazon QuickSight')": 'bi_usa_quicksight',
    "('P4_h_l ', 'Salesforce/Einstein Analytics')": 'bi_usa_salesforce_einstein',
    "('P4_h_m ', 'Mode')": 'bi_usa_mode',
    "('P4_h_n ', 'Alteryx')": 'bi_usa_alteryx',
    "('P4_h_o ', 'Birst')": 'bi_usa_birst',
    "('P4_h_p ', 'Looker')": 'bi_usa_looker',
    "('P4_h_q ', 'Google Data Studio')": 'bi_usa_google_data_studio',
    "('P4_h_r ', 'SAS Visual Analytics')": 'bi_usa_sas_va',
    "('P4_h_s ', 'Grafana')": 'bi_usa_grafana',
    "('P4_h_t ', 'TIBCO Spotfire')": 'bi_usa_tibco',
    "('P4_h_u ', 'Pentaho')": 'bi_usa_pentaho',
    "('P4_h_v ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')": 'bi_usa_excel_gsheets',
    "('P4_h_x ', 'Não utilizo nenhuma ferramenta de BI no trabalho')": 'bi_usa_nenhuma',
    
    # --- Tema: Detalhes sobre Carreiras Específicas ---
    "('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')": 'carreira_experiencia_processos_seletivos',
    "('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')": 'de_rotina_lista',
    "('P6_a_a ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')": 'de_rotina_pipeline_codigo',
    "('P6_a_b ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')": 'de_rotina_etl_ferramentas',
    "('P6_a_c ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')": 'de_rotina_consultas_sql',
    "('P6_a_d ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')": 'de_rotina_integracao_plataformas',
    "('P6_a_e ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')": 'de_rotina_modelagem_arquitetura',
    "('P6_a_f ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')": 'de_rotina_manutencao_datalakes',
    "('P6_a_g ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')": 'de_rotina_modelagem_dados',
    "('P6_a_h ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')": 'de_rotina_qualidade_dados',
    "('P6_a_i ', 'Nenhuma das opções listadas refletem meu dia a dia.')": 'de_rotina_nenhuma_das_opcoes',
    "('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')": 'de_ferramentas_etl_lista',
    "('P6_b_a ', 'Scripts Python')": 'de_etl_scripts_python',
    "('P6_b_b ', 'SQL & Stored Procedures')": 'de_etl_sql_procedures',
    "('P6_b_c ', 'Apache Airflow')": 'de_etl_airflow',
    "('P6_b_d ', 'Luigi')": 'de_etl_luigi',
    "('P6_b_e ', 'AWS Glue')": 'de_etl_aws_glue',
    "('P6_b_f ', 'Talend')": 'de_etl_talend',
    "('P6_b_g ', 'Stitch')": 'de_etl_stitch',
    "('P6_b_h ', 'Fivetran')": 'de_etl_fivetran',
    "('P6_b_i ', 'Google Dataflow')": 'de_etl_google_dataflow',
    "('P6_b_j ', 'Oracle Data Integrator')": 'de_etl_oracle_di',
    "('P6_b_k ', 'IBM DataStage')": 'de_etl_ibm_datastage',
    "('P6_b_l ', 'SAP BW ETL')": 'de_etl_sap_bw',
    "('P6_b_m ', 'SQL Server Integration Services (SSIS)')": 'de_etl_ssis',
    "('P6_b_n ', 'SAS Data Integration')": 'de_etl_sas_di',
    "('P6_b_o ', 'Qlik Sense')": 'de_etl_qlik_sense',
    "('P6_b_p ', 'Knime')": 'de_etl_knime',
    "('P6_b_q ', 'Não utilizo ferramentas de ETL')": 'de_etl_nenhuma',
    "('P6_c ', 'Sua organização possui um Data Lake?')": 'de_empresa_possui_data_lake',
    "('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')": 'de_empresa_tecnologia_data_lake',
    "('P6_e ', 'Sua organização possui um Data Warehouse?')": 'de_empresa_possui_data_warehouse',
    "('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')": 'de_empresa_tecnologia_data_warehouse',
    "('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')": 'de_ferramentas_qualidade_dados_lista',
    "('P6_g_a ', 'great_expectations')": 'de_qualidade_dados_great_expectations',
    "('P6_g_b ', 'dbt')": 'de_qualidade_dados_dbt',
    "('P6_g_c ', 'AWS Deequ')": 'de_qualidade_dados_aws_deequ',
    "('P6_g_d ', 'Apache Griffin')": 'de_qualidade_dados_apache_griffin',
    "('P6_g_e ', 'Datafold')": 'de_qualidade_dados_datafold',
    "('P6_g_f ', 'Amundsen')": 'de_qualidade_dados_amundsen',
    "('P6_g_g ', 'Monte Carlo')": 'de_qualidade_dados_monte_carlo',
    "('P6_g_h ', 'SODA')": 'de_qualidade_dados_soda',
    "('P6_g_i ', 'Big Eye')": 'de_qualidade_dados_big_eye',
    "('P6_g_j ', 'Data Band')": 'de_qualidade_dados_data_band',
    "('P6_g_k ', 'Anomalo')": 'de_qualidade_dados_anomalo',
    "('P6_g_l ', 'Metaplane')": 'de_qualidade_dados_metaplane',
    "('P6_g_m ', 'Acceldata')": 'de_qualidade_dados_acceldata',
    "('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')": 'de_maior_tempo_gasto',
    "('P7_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')": 'da_rotina_lista',
    "('P7_a_a ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')": 'da_rotina_analise_codigo',
    "('P7_a_b ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')": 'da_rotina_dashboards_bi',
    "('P7_a_c ', 'Utilizo API's para extrair dados e complementar minhas análises.')": 'da_rotina_extracao_api',
    "('P7_a_d ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')": 'da_rotina_estatistica_testes',
    "('P7_a_e ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')": 'da_rotina_manutencao_etl',
    "('P7_a_f ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')": 'da_rotina_modelagem_dados',
    "('P7_a_g ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')": 'da_rotina_manutencao_planilhas',
    "('P7_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS')": 'da_rotina_estatistica_avancada',
    "('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')": 'da_ferramentas_etl_lista',
    "('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')": 'da_ferramentas_autonomia_negocios_lista',
    "('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')": 'da_maior_tempo_gasto',
    "('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')": 'ds_rotina_lista',
    "('P8_a_a ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')": 'ds_rotina_estudos_ad_hoc',
    "('P8_a_b ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')": 'ds_rotina_coleta_limpeza',
    "('P8_a_c ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')": 'ds_rotina_contato_negocios',
    "('P8_a_d ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')": 'ds_rotina_desenvolvimento_ml',
    "('P8_a_e ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')": 'ds_rotina_ml_em_producao',
    "('P8_a_f ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')": 'ds_rotina_manutencao_ml',
    "('P8_a_g ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')": 'ds_rotina_dashboards_bi',
    "('P8_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')": 'ds_rotina_estatistica_avancada',
    "('P8_a_j ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')": 'ds_rotina_infraestrutura',
    "('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')": 'ds_tecnicas_lista',
    "('P8_b_a ', 'Utilizo modelos de regressão (linear, logística, GLM)')": 'ds_tecnica_regressao',
    "('P8_b_b ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')": 'ds_tecnica_classificacao_arvores_redes',
    "('P8_b_c ', 'Desenvolvo sistemas de recomendação (RecSys)')": 'ds_tecnica_sistemas_recomendacao',
    "('P8_b_d ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')": 'ds_tecnica_estatistica_bayesiana',
    "('P8_b_e ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')": 'ds_tecnica_nlp',
    "('P8_b_f ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')": 'ds_tecnica_estatistica_classica',
    "('P8_b_g ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')": 'ds_tecnica_markov_hmm',
    "('P8_b_h ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')": 'ds_tecnica_clusterizacao',
    "('P8_b_i ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')": 'ds_tecnica_series_temporais',
    "('P8_b_j ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')": 'ds_tecnica_reinforcement_learning',
    "('P8_b_k ', 'Utilizo modelos de Machine Learning para detecção de fraude')": 'ds_tecnica_deteccao_fraude',
    "('P8_b_l ', 'Utilizo métodos de Visão Computacional')": 'ds_tecnica_visao_computacional',
    "('P8_b_m ', 'Utilizo modelos de Detecção de Churn')": 'ds_tecnica_deteccao_churn',
    "('P8_c ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')": 'ds_tecnologias_lista',
    "('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')": 'dh_iniciativas_acessadas_lista',
    "('P9_a_a ', 'Blog/Medium do Data Hackers')": 'dh_iniciativa_blog',
    "('P9_a_b ', 'Podcast do Data Hackers')": 'dh_iniciativa_podcast',
    "('P9_a_d ', 'Newsletter Semanal')": 'dh_iniciativa_newsletter',
    "('P9_a_e ', 'Canal do Slack')": 'dh_iniciativa_slack',
    "('P9_a_f ', 'Canal do Youtube do Data Hackers')": 'dh_iniciativa_youtube',
    "('P9_a_g ', 'Ainda não conhecia o Data Hackers')": 'dh_iniciativa_nao_conhecia',

    # === MAIOR TEMPO GASTO (Engenheiro de Dados) ===
    "('P6_h_a ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')": 'de_maior_tempo_pipelines_codigo',
    "('P6_h_b ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')": 'de_maior_tempo_etl_ferramentas',
    "('P6_h_c ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')": 'de_maior_tempo_consultas_sql',
    "('P6_h_d ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')": 'de_maior_tempo_integracao_plataformas',
    "('P6_h_e ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')": 'de_maior_tempo_modelagem_arquitetura',
    "('P6_h_f ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')": 'de_maior_tempo_manutencao_datalakes',
    "('P6_h_g ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')": 'de_maior_tempo_modelagem_dados',
    "('P6_h_h ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')": 'de_maior_tempo_qualidade_dados',
    
    # === FERRAMENTAS ETL (Analista de Dados) ===
    "('P7_b_a ', 'Scripts Python')": 'da_etl_scripts_python',
    "('P7_b_b ', 'SQL & Stored Procedures')": 'da_etl_sql_procedures',
    "('P7_b_c ', 'Apache Airflow')": 'da_etl_airflow',
    "('P7_b_d ', 'Luigi')": 'da_etl_luigi',
    "('P7_b_e ', 'AWS Glue')": 'da_etl_aws_glue',
    "('P7_b_f ', 'Talend')": 'da_etl_talend',
    "('P7_b_g ', 'Stitch')": 'da_etl_stitch',
    "('P7_b_h ', 'Fivetran')": 'da_etl_fivetran',
    "('P7_b_i ', 'Google Dataflow')": 'da_etl_google_dataflow',
    "('P7_b_j ', 'Oracle Data Integrator')": 'da_etl_oracle_di',
    "('P7_b_k ', 'IBM DataStage')": 'da_etl_ibm_datastage',
    "('P7_b_l ', 'SAP BW ETL')": 'da_etl_sap_bw',
    "('P7_b_m ', 'SQL Server Integration Services (SSIS)')": 'da_etl_ssis',
    "('P7_b_n ', 'SAS Data Integration')": 'da_etl_sas_di',
    "('P7_b_o ', 'Qlik Sense')": 'da_etl_qlik_sense',
    "('P7_b_p ', 'Knime')": 'da_etl_knime',
    "('P7_b_q ', 'Não utilizo ferramentas de ETL')": 'da_etl_nenhuma',
    
    # === FERRAMENTAS AUTONOMIA NEGÓCIOS (Analista de Dados) ===
    "('P7_c_a ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')": 'da_autonomia_ferramentas_automl',
    '(\'P7_c_b \', \'""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.\')': 'da_autonomia_ferramentas_point_and_click',
    "('P7_c_c ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')": 'da_autonomia_ferramentas_product_insights',
    "('P7_c_d ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')": 'da_autonomia_ferramentas_crm_analytics',
    "('P7_c_e ', 'Minha empresa não utiliza essas ferramentas.')": 'da_autonomia_ferramentas_nenhuma',
    "('P7_c_f ', 'Não sei informar.')": 'da_autonomia_ferramentas_nao_sabe',
    
    # === MAIOR TEMPO GASTO (Analista de Dados) ===
    "('P7_d_a ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')": 'da_maior_tempo_analise_codigo',
    "('P7_d_b ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')": 'da_maior_tempo_dashboards_bi',
    "('P7_d_c ', 'Utilizando API's para extrair dados e complementar minhas análises.')": 'da_maior_tempo_extracao_api',
    "('P7_d_d ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')": 'da_maior_tempo_estatistica_testes',
    "('P7_d_e ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')": 'da_maior_tempo_manutencao_etl',
    "('P7_d_f ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')": 'da_maior_tempo_modelagem_dados',
    "('P7_d_g ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')": 'da_maior_tempo_manutencao_planilhas',
    "('P7_d_h ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')": 'da_maior_tempo_estatistica_avancada',

    # === TECNOLOGIAS (Cientista de Dados) ===
    "('P8_c_a ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')": 'ds_tecnologia_ferramentas_bi',
    "('P8_c_b ', 'Planilhas (Excel, Google Sheets etc)')": 'ds_tecnologia_planilhas',
    "('P8_c_c ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')": 'ds_tecnologia_dev_local',
    "('P8_c_d ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')": 'ds_tecnologia_dev_nuvem',
    "('P8_c_e ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')": 'ds_tecnologia_automl',
    "('P8_c_f ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')": 'ds_tecnologia_etl',
    "('P8_c_g ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')": 'ds_tecnologia_plataformas_ml',
    "('P8_c_h ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')": 'ds_tecnologia_feature_store',
    "('P8_c_i ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')": 'ds_tecnologia_controle_versao',
    "('P8_c_j ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')": 'ds_tecnologia_data_apps',
    "('P8_c_k ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')": 'ds_tecnologia_estatistica_avancada',
    "('P8_c_l ', 'Não utilizo nenhuma dessas ferramentas no meu dia a dia.')": 'ds_tecnologia_nenhuma',

    # === MAIOR TEMPO GASTO (Cientista de Dados) ===
    "('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')": 'ds_maior_tempo_gasto',
    "('P8_d_a ', 'Coletando e limpando os dados que uso para análise e modelagem.')": 'ds_maior_tempo_coleta_limpeza',
    "('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')": 'ds_maior_tempo_contato_negocios',
    "('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')": 'ds_maior_tempo_desenvolvimento_ml',
    "('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')": 'ds_maior_tempo_ml_em_producao',
    "('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')": 'ds_maior_tempo_manutencao_ml',
    "('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')": 'ds_maior_tempo_dashboards_bi',
    "('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')": 'ds_maior_tempo_manutencao_etl',
    "('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')": 'ds_maior_tempo_feature_store_mlops',
    "('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')": 'ds_maior_tempo_infraestrutura'
}

# %%
len(mapa_renomeacao_2021)
# Out:
# 360

# %%
df_2021_kaggle_renomeado = df_2021_kaggle.rename(columns=mapa_renomeacao_2021)

# %%
print(df_2021_kaggle_renomeado.columns.tolist())
# Out:
# ['id_participante', 'idade', 'faixa_idade', 'genero', 'estado_residencia', 'uf_residencia', 'regiao_residencia', 'regiao_origem', 'mudou_de_estado', 'nivel_ensino', 'area_formacao', 'situacao_trabalho', 'setor_atuacao', 'tamanho_empresa', 'atua_como_gestor', 'cargo_gestor', 'cargo_atual', 'nivel_hierarquico', 'faixa_salarial', 'experiencia_dados_anos', 'experiencia_ti_anos', 'satisfacao_trabalho', 'motivos_insatisfacao', 'insatisfacao_fator_falta_crescimento', 'insatisfacao_fator_salario_defasado', 'insatisfacao_fator_relacao_gestor', 'insatisfacao_fator_desejo_mudar_area', 'insatisfacao_fator_beneficios', 'insatisfacao_fator_ambiente_ruim', 'insatisfacao_fator_baixa_maturidade_empresa', 'entrevistas_ultimos_6m', 'planos_mudar_emprego', 'criterios_escolha_emprego', 'criterio_escolha_remuneracao', 'criterio_escolha_beneficios', 'criterio_escolha_proposito', 'criterio_escolha_flexibilidade', 'criterio_escolha_ambiente', 'criterio_escolha_aprendizado', 'criterio_escolha_plano_carreira',
# ...

# %%
df_2021_kaggle_renomeado
# Out:
#                        id_participante  idade faixa_idade     genero  \
# 0     qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s   38.0       35-39  Masculino
# 1     zdl2n19yhgpnoaco6kkczdl2nwv9zwrt   39.0       35-39  Masculino
# 2     vsamqp2un3q7us84mgvsams5fulsmcoh   30.0       30-34  Masculino
# 3     v31ab41botodnsv31zgg4k34zzojy81l   38.0       35-39   Feminino
# 4     ubhu8ntvm4xc0sfkdubhu80e973eek0k   36.0       35-39  Masculino
# ...                                ...    ...         ...        ...
# 2640  07nvo8cdy377a46gon207nvjebwe65zg   40.0       40-44  Masculino
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg   27.0       25-29  Masculino
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18   24.0       22-24  Masculino
# 2643  075h3v2z19if04yn7o075h3vhifl38rw   38.0       35-39  Masculino
# 2644  037usz1h2yip96dgil4mhj037uszw1gk   27.0       25-29   Feminino
#
#         estado_residencia uf_residencia regiao_residencia regiao_origem  \
# ...

# %%
print(f'A lista original tem {len(df_2021_kaggle.columns)} colunas')
print(f'Foram renomeadas {len(mapa_renomeacao_2021)} colunas')
# Out:
# A lista original tem 360 colunas
# Foram renomeadas 360 colunas

# %%
output_path = PROCESSED_DATA_DIR / 'state_of_data_2021_rico_limpo.csv'
df_2021_kaggle_renomeado.to_csv(output_path, index=False)
